# %% [markdown]
# # Final Project - Examining scrapped data from Kijiji and RentFaster using Spark and Yelp API [Partnership with Community Data Program]
#
# **Overview**
#
# In the dynamic field of Data/ML, engaging with Application Programming Interfaces (APIs) is a common practice, enabling the extraction of data or interaction with software. Nonetheless, not all applications/services offer API so it is important to understand how to extract data even in cases where an API is not available. Similarly, adapting to various data management techniques is essential across different companies or organizations. This project centers around gathering data from rental listings within Alberta, Canada, specifically focusing on platforms such as Kijiji and RentFaster. Additionally, you will be leveraging the Yelp API, you'll identify highly rated restaurants and analyze their proximity to these rental listings you scraped from RentFaster and Kijiji.
#
# The data acquisition phase is facilitated through a pre-developed web scraper, designed to streamline the process of extracting rental listings. This initiative is in collaboration with the Community Data Program, aiming to make rental listing data within Canada more accessible to communities with limited access. Initially focusing on Alberta, this project sets the groundwork for future expansion across other regions.
#
# Your task involves determining the pertinent data to extract, followed by managing this data within a distributed system, namely Apache Spark. Subsequently, you will perform data analysis and processing utilizing Spark SQL. This final project encourages collaboration in groups of up to 3 members (you are allowed to use the same members as your midterm), where active participation from all members is expected. It's crucial to note that your presentation will constitute 30% of your overall score, highlighting the importance of both teamwork and individual effort in the successful completion of this project.
#
# **Deliverables**
#
#
# 1.  Your main jupyter notebook file with the proper execution of:
#    *  Part 1: Data Collection
#    *  Part 2: DataFrame, Tables creation and Yelp API setup
#    *  Part 3: Explore your data
# 2.  The data collected from Part 1 in CSV format (Total of 4 CSV files for both Kijiji and RentFaster)
# 3.  A presentation (done using the software of your choosing, PowerPoint, Canvas etc) where you will showcase Part 1 to 3 of your project. What we are specifically looking is the following:
#    *  Issues faced acquiring your data, this could be limitations with the web scraping procedure
#    *  Data quality issues such as missing values or difficulties when working with multiple data types and how to solve/consider those in your analysis
#    *  The highlights and correlations that you derived based on the analysis of the data, you should be able to answer the following questions:
#        * Is there a correlation between the rental price vs the quality/price of restaurants nearby?
#        * Is the data coming from Yelp of enough quality to drive insides?
#        * What would you do better or different to arrive at a more conclusive analysis?
#        * What are your next steps?
#        * Is this data pipeline you built enough to scale for big data?
#
# **Important NOTES**
#
#
# The presentation **IS NOT GOING TO BE A RECORDING**. It will be a live presentation either in-person or online where I will engage in questions with all of the team. If a member is not present, that person will lose automatically 30% of the total grade of the Final.
#
#
# *InPerson Students*
#
#
# *  The presentation will be held in-person on Monday April 22nd and Tuesday
# April 23rd (time to be decided).
#
#
# *Hyflex Students*
# *  You have the opportunity to present in-person (if you can make it) or schedule an online presentation with me. Either way you need to let me know
#
#
# **Due Date** You have until Saturday April 20th at Midnight to submit your code. But you still have time to work on your presentation as the presentation will be held on the 22th and 23th.

# %% [markdown]
# ## Web Scraping Code
# In this section you will find everything you need to know about the Scraper we have built for you to get data from rentals within AB from RentFaster and Kijiji

# %% [markdown]
# ### Working with PlayWright
#
# Playwright is a tool developed by Microsoft that allows developers to automate interactions with web browsers. In simpler terms, it can control browsers programmatically to perform tasks like navigating through web pages, clicking buttons, filling out forms, and extracting information from websites, all through a script or program.
#
# Here’s why Playwright is particularly useful for web scraping rental listings in RentFaster and Kijiji:
# 1. **Supports Multiple Browsers**: Playwright can control different browsers (like Chrome, Firefox, and Safari) using a single API. This makes it easier to scrape websites as they appear in various browsers without needing to adjust your code significantly for each one.
#
# 2. **Headless Browsing**: It can run browsers in 'headless' mode, meaning it can navigate and interact with websites without actually opening a browser window. This speeds up the scraping process and allows for running scrapers on servers or in environments where a graphical interface is not available.
#
# 3. **Automates Complex Interactions**: Some websites require complex interactions to access their data, like logging in, navigating through menus, or interacting with JavaScript. Playwright can automate these interactions, making it possible to scrape data from sites that would be difficult or impossible to scrape with simpler tools.
#
# Learn more about it! https://playwright.dev/python/docs/intro

# %%
# !pip install playwright
# !playwright install
# Out:
# Collecting playwright
#   Downloading playwright-1.43.0-py3-none-manylinux1_x86_64.whl (37.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: greenlet==3.0.3 in /usr/local/lib/python3.10/dist-packages (from playwright) (3.0.3)
# Collecting pyee==11.1.0 (from playwright)
#   Downloading pyee-11.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee==11.1.0->playwright) (4.11.0)
# Installing collected packages: pyee, playwright
# Successfully installed playwright-1.43.0 pyee-11.1.0
# Downloading Chromium 124.0.6367.29 (playwright build v1112) from https://playwright.azureedge.net/builds/chromium/1112/chromium-linux.zip
# 155.3 MiB [] 0% 0.0s155.3 MiB [] 0% 40.1s155.3 MiB [] 0% 21.1s155.3 MiB [] 0% 12.1s155.3 MiB [] 0% 11.6s155.3 MiB [] 0% 10.0s155.3 MiB [] 1% 8.8s155.3 MiB [] 1% 8.4s155.3 MiB [] 1% 7.9s155.3 MiB [] 1% 7.7s155.3 MiB [] 2% 7.5s155.3 MiB [] 2% 7.4s155.3 MiB [] 2% 7.6s155.3 MiB [] 3% 7.5s155.3 MiB [] 3% 7.4s155.3 MiB [] 3% 7.2s155.3 MiB [] 3% 6.9s155.3 MiB [] 4% 6.8s155.3 MiB [] 4% 6.9s155.3 MiB [] 4% 7.1s155.3 MiB [] 4% 7.3s155.3 MiB [] 4% 7.5s155.3 MiB [] 4% 7.4s155.3 MiB [] 5% 7.4s155.3 MiB [] 5% 7.7s155.3 MiB [] 5% 7.9s155.3 MiB [] 5% 8.0s155.3 MiB [] 5% 8.1s155.3 MiB [] 5% 8.0s155.3 MiB [] 6% 7.8s155.3 MiB [] 6% 7.7s155.3 MiB [] 6% 7.4s155.3 MiB [] 7% 7.2s155.3 MiB [] 7% 7.0s155.3 MiB [] 8% 6.9s155.3 MiB [] 8% 6.8s155.3 MiB [] 9% 6.7s155.3 MiB [] 10% 6.6s155.3 MiB [] 10% 6.4s155.3 MiB [] 11% 6.4s155.3 MiB [] 11% 6.2s155.3 MiB [] 11% 6.3s155.3 MiB [] 11% 6.4s155.3 MiB [] 12% 6.4s155.3 MiB [] 12% 6.3s155.3 MiB [] 12% 6.4s155.3 MiB [] 13% 6.3s155.3 MiB [] 13% 6.4s155.3 MiB [] 13% 6.9s155.3 MiB [] 13% 7.0s155.3 MiB [] 14% 7.1s155.3 MiB [] 14% 7.2s155.3 MiB [] 14% 7.3s155.3 MiB [] 14% 7.4s155.3 MiB [] 14% 7.5s155.3 MiB [] 14% 7.6s155.3 MiB [] 14% 7.7s155.3 MiB [] 14% 7.8s155.3 MiB [] 15% 7.8s155.3 MiB [] 15% 7.9s155.3 MiB [] 15% 8.0s155.3 MiB [] 15% 8.1s155.3 MiB [] 16% 8.0s155.3 MiB [] 16% 7.9s155.3 MiB [] 17% 7.9s155.3 MiB [] 17% 7.8s155.3 MiB [] 18% 7.8s155.3 MiB [] 18% 7.9s155.3 MiB [] 18% 7.8s155.3 MiB [] 19% 7.7s155.3 MiB [] 19% 7.8s155.3 MiB [] 20% 7.6s155.3 MiB [] 20% 7.5s155.3 MiB [] 21% 7.5s155.3 MiB [] 21% 7.4s155.3 MiB [] 21% 7.5s155.3 MiB [] 21% 7.6s155.3 MiB [] 22% 7.6s155.3 MiB [] 22% 7.7s155.3 MiB [] 23% 7.7s155.3 MiB [] 23% 7.6s155.3 MiB [] 23% 7.7s155.3 MiB [] 24% 7.6s155.3 MiB [] 24% 7.5s155.3 MiB [] 25% 7.5s155.3 MiB [] 25% 7.4s155.3 MiB [] 26% 7.3s155.3 MiB [] 26% 7.2s155.3 MiB [] 27% 7.2s155.3 MiB [] 27% 7.1s155.3 MiB [] 28% 7.0s155.3 MiB [] 28% 6.9s155.3 MiB [] 29% 6.8s155.3 MiB [] 30% 6.6s155.3 MiB [] 31% 6.5s155.3 MiB [] 31% 6.4s155.3 MiB [] 32% 6.2s155.3 MiB [] 32% 6.1s155.3 MiB [] 33% 6.1s155.3 MiB [] 33% 6.0s155.3 MiB [] 33% 5.9s155.3 MiB [] 34% 5.9s155.3 MiB [] 35% 5.8s155.3 MiB [] 35% 5.7s155.3 MiB [] 35% 5.6s155.3 MiB [] 35% 5.7s155.3 MiB [] 36% 5.6s155.3 MiB [] 37% 5.5s155.3 MiB [] 37% 5.4s155.3 MiB [] 38% 5.3s155.3 MiB [] 38% 5.2s155.3 MiB [] 39% 5.2s155.3 MiB [] 40% 5.2s155.3 MiB [] 40% 5.1s155.3 MiB [] 41% 5.0s155.3 MiB [] 42% 4.9s155.3 MiB [] 43% 4.8s155.3 MiB [] 44% 4.7s155.3 MiB [] 44% 4.6s155.3 MiB [] 45% 4.5s155.3 MiB [] 46% 4.3s155.3 MiB [] 47% 4.2s155.3 MiB [] 47% 4.1s155.3 MiB [] 48% 4.0s155.3 MiB [] 49% 3.9s155.3 MiB [] 50% 3.8s155.3 MiB [] 50% 3.7s155.3 MiB [] 51% 3.7s155.3 MiB [] 52% 3.6s155.3 MiB [] 52% 3.5s155.3 MiB [] 53% 3.4s155.3 MiB [] 54% 3.3s155.3 MiB [] 55% 3.2s155.3 MiB [] 56% 3.1s155.3 MiB [] 57% 3.0s155.3 MiB [] 58% 2.9s155.3 MiB [] 60% 2.7s155.3 MiB [] 61% 2.5s155.3 MiB [] 62% 2.4s155.3 MiB [] 63% 2.4s155.3 MiB [] 65% 2.2s155.3 MiB [] 66% 2.1s155.3 MiB [] 68% 2.0s155.3 MiB [] 69% 1.9s155.3 MiB [] 70% 1.8s155.3 MiB [] 71% 1.7s155.3 MiB [] 73% 1.6s155.3 MiB [] 74% 1.5s155.3 MiB [] 75% 1.4s155.3 MiB [] 76% 1.3s155.3 MiB [] 77% 1.3s155.3 MiB [] 77% 1.2s155.3 MiB [] 78% 1.2s155.3 MiB [] 79% 1.2s155.3 MiB [] 79% 1.1s155.3 MiB [] 80% 1.1s155.3 MiB [] 81% 1.0s155.3 MiB [] 82% 0.9s155.3 MiB [] 83% 0.9s155.3 MiB [] 84% 0.8s155.3 MiB [] 85% 0.8s155.3 MiB [] 86% 0.7s155.3 MiB [] 87% 0.7s155.3 MiB [] 88% 0.6s155.3 MiB [] 89% 0.6s155.3 MiB [] 89% 0.5s155.3 MiB [] 90% 0.5s155.3 MiB [] 91% 0.5s155.3 MiB [] 91% 0.4s155.3 MiB [] 92% 0.4s155.3 MiB [] 93% 0.4s155.3 MiB [] 93% 0.3s155.3 MiB [] 94% 0.3s155.3 MiB [] 95% 0.3s155.3 MiB [] 95% 0.2s155.3 MiB [] 96% 0.2s155.3 MiB [] 97% 0.1s155.3 MiB [] 98% 0.1s155.3 MiB [] 99% 0.0s155.3 MiB [] 100% 0.0s
# Chromium 124.0.6367.29 (playwright build v1112) downloaded to /root/.cache/ms-playwright/chromium-1112
# Downloading FFMPEG playwright build v1009 from https://playwright.azureedge.net/builds/ffmpeg/1009/ffmpeg-linux.zip
# 2.6 MiB [] 0% 0.0s2.6 MiB [] 3% 0.4s2.6 MiB [] 9% 0.3s2.6 MiB [] 28% 0.1s2.6 MiB [] 37% 0.1s2.6 MiB [] 56% 0.1s2.6 MiB [] 89% 0.0s2.6 MiB [] 100% 0.0s
# FFMPEG playwright build v1009 downloaded to /root/.cache/ms-playwright/ffmpeg-1009
# Downloading Firefox 124.0 (playwright build v1447) from https://playwright.azureedge.net/builds/firefox/1447/firefox-ubuntu-22.04.zip
# 85.4 MiB [] 0% 0.0s85.4 MiB [] 0% 16.5s85.4 MiB [] 0% 13.3s85.4 MiB [] 0% 6.5s85.4 MiB [] 1% 4.1s85.4 MiB [] 2% 3.4s85.4 MiB [] 3% 2.8s85.4 MiB [] 4% 2.5s85.4 MiB [] 4% 2.6s85.4 MiB [] 5% 2.6s85.4 MiB [] 5% 2.7s85.4 MiB [] 6% 2.6s85.4 MiB [] 7% 2.6s85.4 MiB [] 7% 2.7s85.4 MiB [] 8% 2.8s85.4 MiB [] 9% 2.5s85.4 MiB [] 10% 2.5s85.4 MiB [] 11% 2.4s85.4 MiB [] 12% 2.3s85.4 MiB [] 12% 2.2s85.4 MiB [] 13% 2.2s85.4 MiB [] 14% 2.1s85.4 MiB [] 15% 2.1s85.4 MiB [] 16% 2.0s85.4 MiB [] 17% 2.0s85.4 MiB [] 19% 1.9s85.4 MiB [] 20% 1.8s85.4 MiB [] 21% 1.8s85.4 MiB [] 22% 1.7s85.4 MiB [] 23% 1.8s85.4 MiB [] 24% 1.7s85.4 MiB [] 25% 1.7s85.4 MiB [] 26% 1.7s85.4 MiB [] 27% 1.6s85.4 MiB [] 28% 1.6s85.4 MiB [] 29% 1.6s85.4 MiB [] 30% 1.5s85.4 MiB [] 31% 1.5s85.4 MiB [] 32% 1.5s85.4 MiB [] 33% 1.4s85.4 MiB [] 35% 1.3s85.4 MiB [] 36% 1.3s85.4 MiB [] 37% 1.3s85.4 MiB [] 39% 1.2s85.4 MiB [] 40% 1.2s85.4 MiB [] 42% 1.1s85.4 MiB [] 44% 1.1s85.4 MiB [] 45% 1.0s85.4 MiB [] 46% 1.0s85.4 MiB [] 47% 1.0s85.4 MiB [] 49% 0.9s85.4 MiB [] 50% 0.9s85.4 MiB [] 52% 0.8s85.4 MiB [] 53% 0.8s85.4 MiB [] 54% 0.8s85.4 MiB [] 56% 0.8s85.4 MiB [] 57% 0.7s85.4 MiB [] 59% 0.7s85.4 MiB [] 60% 0.7s85.4 MiB [] 62% 0.6s85.4 MiB [] 64% 0.6s85.4 MiB [] 65% 0.6s85.4 MiB [] 66% 0.5s85.4 MiB [] 68% 0.5s85.4 MiB [] 69% 0.5s85.4 MiB [] 70% 0.5s85.4 MiB [] 72% 0.4s85.4 MiB [] 74% 0.4s85.4 MiB [] 76% 0.4s85.4 MiB [] 78% 0.3s85.4 MiB [] 80% 0.3s85.4 MiB [] 81% 0.3s85.4 MiB [] 82% 0.3s85.4 MiB [] 84% 0.2s85.4 MiB [] 86% 0.2s85.4 MiB [] 88% 0.2s85.4 MiB [] 90% 0.1s85.4 MiB [] 92% 0.1s85.4 MiB [] 93% 0.1s85.4 MiB [] 95% 0.1s85.4 MiB [] 97% 0.0s85.4 MiB [] 100% 0.0s
# Firefox 124.0 (playwright build v1447) downloaded to /root/.cache/ms-playwright/firefox-1447
# Downloading Webkit 17.4 (playwright build v1992) from https://playwright.azureedge.net/builds/webkit/1992/webkit-ubuntu-22.04.zip
# 86.5 MiB [] 0% 0.0s86.5 MiB [] 0% 14.8s86.5 MiB [] 0% 13.1s86.5 MiB [] 0% 7.3s86.5 MiB [] 1% 6.1s86.5 MiB [] 1% 5.7s86.5 MiB [] 1% 5.1s86.5 MiB [] 2% 4.7s86.5 MiB [] 2% 4.4s86.5 MiB [] 3% 4.2s86.5 MiB [] 4% 3.9s86.5 MiB [] 5% 3.8s86.5 MiB [] 5% 3.9s86.5 MiB [] 6% 3.6s86.5 MiB [] 7% 3.4s86.5 MiB [] 7% 3.5s86.5 MiB [] 7% 3.8s86.5 MiB [] 8% 3.8s86.5 MiB [] 9% 3.8s86.5 MiB [] 9% 3.7s86.5 MiB [] 10% 3.7s86.5 MiB [] 11% 3.4s86.5 MiB [] 11% 3.5s86.5 MiB [] 12% 3.4s86.5 MiB [] 13% 3.3s86.5 MiB [] 14% 3.2s86.5 MiB [] 15% 3.1s86.5 MiB [] 15% 3.0s86.5 MiB [] 16% 2.9s86.5 MiB [] 16% 3.0s86.5 MiB [] 17% 3.0s86.5 MiB [] 17% 2.9s86.5 MiB [] 18% 2.9s86.5 MiB [] 19% 2.8s86.5 MiB [] 20% 2.7s86.5 MiB [] 21% 2.5s86.5 MiB [] 22% 2.4s86.5 MiB [] 23% 2.4s86.5 MiB [] 24% 2.3s86.5 MiB [] 25% 2.2s86.5 MiB [] 27% 2.1s86.5 MiB [] 28% 2.0s86.5 MiB [] 29% 2.0s86.5 MiB [] 30% 1.9s86.5 MiB [] 31% 1.9s86.5 MiB [] 33% 1.8s86.5 MiB [] 35% 1.6s86.5 MiB [] 37% 1.5s86.5 MiB [] 38% 1.5s86.5 MiB [] 40% 1.4s86.5 MiB [] 42% 1.3s86.5 MiB [] 44% 1.2s86.5 MiB [] 45% 1.2s86.5 MiB [] 47% 1.1s86.5 MiB [] 48% 1.1s86.5 MiB [] 49% 1.0s86.5 MiB [] 51% 1.0s86.5 MiB [] 54% 0.9s86.5 MiB [] 56% 0.8s86.5 MiB [] 58% 0.8s86.5 MiB [] 60% 0.7s86.5 MiB [] 62% 0.7s86.5 MiB [] 64% 0.6s86.5 MiB [] 66% 0.6s86.5 MiB [] 67% 0.6s86.5 MiB [] 70% 0.5s86.5 MiB [] 72% 0.5s86.5 MiB [] 74% 0.4s86.5 MiB [] 76% 0.4s86.5 MiB [] 78% 0.3s86.5 MiB [] 79% 0.3s86.5 MiB [] 82% 0.3s86.5 MiB [] 83% 0.3s86.5 MiB [] 85% 0.2s86.5 MiB [] 87% 0.2s86.5 MiB [] 89% 0.2s86.5 MiB [] 91% 0.1s86.5 MiB [] 93% 0.1s86.5 MiB [] 95% 0.1s86.5 MiB [] 97% 0.0s86.5 MiB [] 98% 0.0s86.5 MiB [] 99% 0.0s86.5 MiB [] 100% 0.0s
# Webkit 17.4 (playwright build v1992) downloaded to /root/.cache/ms-playwright/webkit-1992
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:216:9)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:587:43)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:685:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:674:43)
#     at async t.<anonymous> (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/cli/program.js:119:7)

# %% [markdown]
# ### Web Scraping Libraries - Explained
#
# When scraping rental listings from websites like Kijiji and RentFaster, several Python libraries will be of use in the process. Here's how each of them contributes:
#
# - **`asyncio`**: This is a library to write concurrent code using the async/await syntax. It is useful for handling asynchronous operations, making it possible to scrape websites more efficiently. When used with `playwright`, it allows for asynchronous navigation and interaction with web pages, speeding up the web scraping process by performing multiple tasks concurrently.
#
# - **`json`**: JavaScript Object Notation (JSON) is a lightweight data interchange format. This library can be used to parse JSON data that will be returned from HTML requests on rental websites and to store scraped data in a JSON format, making it easier to work with complex data structures using Spark.
#
# - **`requests`**: A powerful HTTP library for making requests to web servers. It is used to request the HTML content of web pages from Kijiji and RentFaster. `requests` is straightforward and can handle various types of HTTP requests, essential for accessing the data on rental listings.
#
# - **`time`**: This module provides various time-related functions. We will use it to handle rate limiting by adding delays between requests, ensuring that your scraping activities do not lead to your IP being banned from the website for making too many requests too quickly.
#
# - **`re` (Regular Expression)**: This library is used to search, match, or replace patterns in strings. In our web scraping process, is particularly useful for extracting specific pieces of data from HTML or text, such as phone numbers, prices, or other structured information from rental listings.
#
# - **`pandas` (pd)**: A powerful data manipulation and analysis library. After scraping the data, `pandas` can be used to clean, transform, and analyze the rental listings data, making it easier to work with large datasets and perform complex data analysis tasks.
#
# - **`csv`**: This module implements classes to read and write tabular data in CSV format. It can be used to save scraped data into CSV files, which is a common format for storing tabular data, allowing for easy sharing and analysis of the scraped rental listings.
#
# - **`BeautifulSoup` (from `bs4`)**: A library for parsing HTML and XML documents. It creates parse trees that is helpful to extract information from web pages easily. `BeautifulSoup` works well with `requests` to navigate the HTML structure of a page and extract data, such as rental prices, descriptions, and images.
#
# - **`playwright.async_api` (async_playwright, TimeoutError)**: `playwright` is a framework for browser automation and `async_playwright` refers to its asynchronous API. This is particularly useful for interacting with JavaScript-heavy websites like RentFaster, allowing for headless browser interaction, page navigation, and dynamic content loading. The `TimeoutError` helps in handling exceptions that may occur if a page takes too long to load or respond.

# %%
import asyncio
import json
import requests
import time
import re
import pandas as pd
import csv
import numpy as np
from bs4 import BeautifulSoup
# Import async playwright
from playwright.async_api import async_playwright, TimeoutError, Error

# %% [markdown]
# ### Get HTML content from Website - PlayWright
#
# The `get_page_content` function is an asynchronous utility designed for web scraping, specifically optimized for fetching content from RentFaster and Kijiji. It employs the Playwright library to programmatically control a web browser, navigating to a specified URL and waiting for the page to load fully before capturing its HTML content. This is particularly useful for RentFaster that dynamicaly loads content asynchronously with JavaScript.
#
# The function is capable of making multiple attempts to fetch a page's content, retrying up to a predefined limit in case of timeouts, which can occur with Kijiji. This retry mechanism, coupled with the ability to wait for specific page elements to appear before proceeding, ensures reliability in the scraping process. It can specifically wait for elements that signify the page has fully loaded on either RentFaster or Kijiji, based on parameters passed to it. After successfully retrieving the page content, the browser session is closed to clean up resources. If the function fails to fetch the content after the specified number of retries, it raises an exception to signal the failure. This approach ensures robustness and flexibility in scraping tasks, accommodating the challenges posed these websites.

# %%
async def get_page_content(url, wait_rf, wait_kk, retries=5):
    attempt = 0
    while attempt < retries:
        try:
            async with async_playwright() as p:
                # Launch the browser
                browser = await p.chromium.launch()
                page = await browser.new_page()

                # Navigate to the URL
                await page.goto(url)
                if wait_rf:
                    # Wait for a selector to ensure the page has loaded (rent-faster)
                    await page.wait_for_selector('.card.my-3.p-3.ng-scope', timeout=6000)
                if wait_kk:
                    # Wait for a selector to ensure the page has loaded (kijiji)
                    await page.wait_for_selector('ul[data-testid="srp-search-list"]', timeout=6000)
                await asyncio.sleep(1)
                # Get the page content
                content = await page.content()
                # Close the browser
                await browser.close()

                return content
        except (TimeoutError, Error) as e:
            print(f"Attempt {attempt + 1} failed with error {e}, retrying...")
            attempt += 1
            if attempt < retries:
                await asyncio.sleep(2)  # Wait a bit before retrying

    # If all attempts fail, raise an exception or return a specific value
    raise Exception(f"All {retries} attempts failed.")

# %% [markdown]
# ### Retrieve URLs from listing website -   Kijiji
# The `get_urls_kk` function is an asynchronous function crafted to parse URLs from the HTML content of a Kijiji listing page, a task preceded by fetching the page content with the `get_page_content` function. Utilizing the BeautifulSoup library, the function interprets the HTML to find specific anchor (`<a>`) tags that denote listing links on Kijiji.
#
# This method is finely tuned for the structure of Kijiji's website, making use of distinct HTML attributes to precisely extract and construct URLs for each listing. It plays an essential role in web scraping workflows aimed at navigating from a general listings page to specific listings for more detailed data extraction.

# %%
async def get_urls_kk(content):
    soup = BeautifulSoup(content, 'html.parser')
    urls = []
    links = soup.find_all('a', {'data-testid': 'listing-link'}, href=True)
    for link in links:
        urls.append('https://www.kijiji.ca' + link['href'])
    return urls

# %% [markdown]
# ### Retrieve URLs from listing website - RentFaster
#
# The `get_urls_rf` function is designed to extract URLs from the HTML content of a RentFaster listing page. Unlike the previous function focused on Kijiji, this one deals with structured data embedded within a `<script>` tag in JSON format, a common technique for web developers to initialize JavaScript objects on web pages.
#
# This function highlights a different approach to web scraping, focusing on extracting data from JSON embedded within HTML content, which can be a more direct and less error-prone method than parsing the HTML structure itself, especially when the website utilizes JavaScript to render content dynamically.

# %%
back_up_details = {}
back_up_overviews = {}

def get_urls_rf(content):
    soup = BeautifulSoup(content, 'html.parser')
    script_tag = soup.find('script', id='ldjsonProperties')
    json_str = script_tag.string if script_tag else ''

    # Check if we successfully found the script tag and extracted the string
    if not json_str:
        print("JSON string not found.")
    else:
        data = json.loads(json_str)
        urls = []
        # Check if the key 'itemListElement' is in the parsed data
        if 'itemListElement' in data:
            # Iterate through each item and extract the 'url'
            for item in data['itemListElement']:
                url = item.get('url', None)
                if url:
                    urls.append(url)
        return urls

# %% [markdown]
# ### Generate URLs from both website programmatically
#
# This functions deals with creating a list of listings and their URLs for both Kijiji and RentFaster. It is designed to call the functions we defined above based on the following parameters:
#
#
# *   `parameter` : Can be the a location within Alberta if `rentfaster` is `True`, or it can be a `page` number based on which page from a listing we want to get the URLs from if `kijiji` is `True`
# *   `kijiji`: Boolean True or False
# *   `rentfaster`: Boolean True or False

# %%
async def url_generator(parameter,kijiji,rentfaster):
  contents_urls = []
  if rentfaster:
    for location in parameter:
      url = f'https://www.rentfaster.ca/ab/{location}/#dialog-listview'
      content = await get_page_content(url,True,False)
      time.sleep(1)
      print(f"Getting listing URLs for {location} [RentFaster]")
      urls = get_urls_rf(content)
      contents_urls.append(urls)
      time.sleep(1)
    print("URLs retrieved")
    return contents_urls
  elif kijiji:
    for n in range(1, len(parameter) + 1):
      url = f"https://www.kijiji.ca/b-for-rent/alberta/page-{parameter[n-1]}/c30349001l9003"
      print(f"Getting listing URLs for AB page {parameter[n-1]} [Kijiji]")
      content = await get_page_content(url, wait_rf = False, wait_kk = True)
      time.sleep(1)
      urls = await get_urls_kk(content)
      contents_urls.append(urls)
      time.sleep(1)
    print("URLs retrieved")
    return contents_urls
  else:
    print("Invalid Options")
    return None

# %% [markdown]
# ### Scraping and Parsing content from Website
# To understand the structure and dynamics of HTML content fetched from Kijiji and RentFaster is important to effectively use web scraping, especially when extracting detailed information about rental listings. This complexity arises because websites such as RentFaster often employ dynamic content loading through JavaScript, which means the data you're interested in (e.g., address, price, listing title, description, features of the listing like pet-friendliness or laundry facilities, contact info, posting date, URL) may not be present in the initial HTML served by the web server but loaded asynchronously thereafter.
#
# Given these challenges, tailored approaches are necessary for scraping each website. These functions are meticulously designed to navigate the intricacies of each site's HTML structure and JavaScript dynamics.
#
# RentFaster, for instance, stores relevant listing details within `<script>` tags in JSON format. The parsing function for RentFaster content is adept at locating these tags, extracting and decoding the JSON, and then systematically pulling out and organizing the necessary data, such as property overview, amenities, and unit details. This method hinges on the JSON being structured in a predictable manner, allowing for direct access to various pieces of information without the need to interpret the HTML visually as a browser would.
#
# On the other hand, the Kijiji content parsing function deals with a more traditional mix of HTML elements and embedded JSON scripts. It has to navigate through the document, identifying specific tags and classes to extract the listing’s description, address, and other attributes. This function also handles dynamically loaded data, requiring it to parse both the visible HTML and the JavaScript variables or window properties that contain JSON data with additional details about the listings.
#
# The need for these tailored functions arise from the variance in how each website delivers content to the end-user. While one site might embed data within HTML in a straightforward manner, another might rely heavily on JavaScript to construct the page dynamically, necessitating a flexible and nuanced approach to scraping.
#
# This project highlights a broader principle in web scraping: the importance of carefully analyzing the source content of a website to understand how it structures and delivers data. This analysis is crucial for designing efficient scrapers that can reliably extract the needed information despite the complexities of modern web development practices, including the use of JavaScript and AJAX for dynamic content loading. Such an understanding not only informs the technical strategy for data extraction but also ensures the scraper can adapt to changes in the website's structure or content delivery mechanisms over time.

# %%
# @title #### RentFaster Parser Function
def parse_json_data_rf(content, url):
    soup = BeautifulSoup(content, 'html.parser')
    script_tags = soup.find_all("script", type="application/ld+json")
    match = re.search(r'https://www\.rentfaster\.ca(/[^/]+/[^/]+)/', url)
    location = match.group(1)
    data = None
    for tag in script_tags:
        try:
            if tag.string != None:
              json_data = json.loads(tag.string)
              if 'mainEntity' in json_data:
                  data = json_data['mainEntity']
                  break
        except json.JSONDecodeError:
            continue

    if data is None:
      print("No valid JSON data found for the provided listing. Skipping Listing")
      return
    # Extract the ID from the URL
    property_id = re.search(r'(\d+)$', data.get("@id", "")).group(1) if data.get("@id") else None

    property_overview = {
        "id": property_id,
        "location": location,
        "name": data.get("name", "Undefined"),
        "url": data.get("url", "Undefined"),
        "slogan": data.get("slogan", "Undefined"),
        "priceRange": data.get("priceRange", "Undefined"),
        "telephone": data.get("telephone", "Undefined"),
        "image": data.get("image", "Undefined"),
        "description": data.get("description", "Undefined")
    }
    if "address" in data:
      address_parts = [
          data["address"].get("streetAddress", ""),
          data["address"].get("addressLocality", ""),
          data["address"].get("addressRegion", ""),
          data["address"].get("postalCode", ""),
          data["address"]["addressCountry"].get("name", "")
      ]
      # Filter out empty strings and join with a comma
      property_overview["address"] = ', '.join(filter(None, address_parts))
    else:
      property_overview["address"] = "Undefined"

    # Conditionally add amenities if they exist
    if "amenityFeature" in data:
      property_overview["amenities"] = {feature.get("name", ""): feature.get("value", "") for feature in data["amenityFeature"]}
    else:
      property_overview["amenities"] = {"Undefined"}

    # Update the global dictionary for property overviews
    all_property_overviews[property_id] = property_overview

    # Extract and restructure unit details
    unit_details = [
        {
            "property_id": property_id,  # Link to property by ID
            "unit_name": unit["name"],
            "description": unit["description"],
            "squareFeet": next((prop["value"] for prop in unit["additionalProperty"] if prop["name"] == "Square Feet"), None),
            "availabilityDate": next((prop["value"] for prop in unit["additionalProperty"] if prop["name"] == "Availability Date"), None),
            "utilitiesIncluded": next((prop["value"] for prop in unit["additionalProperty"] if prop["name"] == "Utilities Included"), None)
        } for unit in data.get("containsPlace", [])
    ]

    for unit_detail in unit_details:
        # Sanitize the unit_name to remove spaces and special characters for use as a key
        sanitized_unit_name = re.sub(r'\W+', '_', unit_detail["unit_name"])  # Replace non-word characters with underscore
        key = f'{property_id}_{sanitized_unit_name}'
        all_unit_details[key] = unit_detail

# %%
# @title #### Kijiji Parser Function
def parse_json_data_kk(content, link):

  script_content_var = None
  script_content_window = None
  match_link = re.search(r'/(\d+)$', link)
  property_id = match_link.group(1)
  soup = BeautifulSoup(content, 'html.parser')

  # Find the meta tag with the name 'description'
  description_container = soup.find('div', class_='descriptionContainer-2067035870')
  if description_container and description_container.div:
      description = description_container.div.get_text(separator='\n').strip()
  else:
      description = "Undefined"

  # Find address
  adLocation_tags = soup.find_all('span', itemprop="address")

  adLocation = {f"address_{index+1}": tag.get_text().strip()
                    for index, tag in enumerate(adLocation_tags)} if adLocation_tags else {"Undefined": "Undefined"}

  # Find date posted - Assuming this extracts the text correctly, or you might need to adjust based on actual content
  date = soup.select_one("div[class*=datePosted-1776470403]").get_text() if soup.select_one("div[class*=datePosted-1776470403]") else "Undefined"

  script_tag_var = soup.find('script', string=re.compile('var dataLayer ='))
  if script_tag_var is not None:
      script_content_var = script_tag_var.string
      match_var = re.search(r'var dataLayer = (\[.*?\]);', script_content_var, re.DOTALL)
      if match_var:
        data_layer = json.loads(match_var.group(1))
        item = data_layer[0]
        price_info = item.get('a', {}).get('prc', {})
  else:
    price_info = "Undefined"

  script_tag_window = soup.find('script', string=re.compile('window\.__data'))
  if script_tag_window is not None:
      script_content_window = script_tag_window.string
      match_window = re.search(r'window\.__data=(\{.*?\});', script_content_window, re.DOTALL)
      if match_window:
        data = json.loads(match_window.group(1))
        ad_info = data.get("config", {}).get("VIP", {})
        ad_location = ad_info.get("adLocation", {})
        ad_attributes = ad_info.get("adAttributes", {})
        attributes_dict = {}
        for attr in ad_attributes:
          label = attr['localeSpecificValues']['en']['label']
          value = attr['localeSpecificValues']['en']['value']
          attributes_dict[label] = value
  else:
    attributes_dict = "Undefined"

  all_property_overviews_kk[property_id] = {
      "listing_url": link,
      "date_posted": date,
      "address" : adLocation,
      "price_info": price_info,
      "description": description
  }
  all_unit_details_kk[property_id] = attributes_dict

# %%
# @title #### Parser based on CSV with URLs
async def scrape_urls_from_csv(filename,website):
    urls = []
    # Read URLs from CSV
    with open(filename, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            if row:  # Check if the row is not empty
                urls.append(row[0])
    total_urls = len(urls)
    print(f"URLs extracted from the CSV file: {filename}. Total URLs to scrape: {total_urls}")

    # Scraping loop
    for index, url in enumerate(urls, start=1):
        content = await get_page_content(str(url), wait_rf=False, wait_kk=False)
        print(f"Scraping started for {url}. [{index}/{total_urls}]")
        await asyncio.sleep(0.5)
        if website == 'kijiji':
          parse_json_data_kk(content, url)
        elif website == 'rentfaster':
          parse_json_data_rf(content, url)
        print(f"Scraped {index} urls out of {total_urls} total.")

    print("Scraping Finished")

# %% [markdown]
# ### Data Transformation Toolkit
# General functions to covert data into CSV and DataFrame

# %%
# @title #### Create csv - RentFaster/Kijiji
def convert_to_tables(all_property_overviews, all_unit_details, filename_overview, filename_details):
    # Convert dictionaries to dataframes, including the keys as a new column
    property_overviews_df = pd.DataFrame.from_dict(all_property_overviews, orient='index').reset_index()
    unit_details_df = pd.DataFrame.from_dict(all_unit_details, orient='index').reset_index()

    # Rename the 'index' column to 'property_id'
    property_overviews_df.rename(columns={'index': 'property_id'}, inplace=True)
    unit_details_df.rename(columns={'index': 'property_id'}, inplace=True)

    # Example: Save to CSV
    property_overviews_df.to_csv(filename_overview, index=False)
    unit_details_df.to_csv(filename_details, index=False)

def convert_rentfaster_to_csv(all_unit_details,all_property_overviews,csv_file_path_details,csv_file_path_overview):
    #converting details data into csv
    df_details = pd.DataFrame.from_dict(all_unit_details, orient='index').reset_index().rename(columns={'index':'unit_id'})
    df_details['description'] = df_details['description'].str.replace(',','')
    df_details['unit_name'] = df_details['unit_name'].str.replace(',','')
    df_details.to_csv(csv_file_path_details, index=False)

    #converting overview data into csv
    df_o = pd.DataFrame.from_dict(all_property_overviews, orient='index').reset_index().rename(columns={'index':'property_id'})
    df_o['description'] = df_o['description'].apply(lambda x: re.sub(r'[^A-Za-z0-9 ]+', '', x))
    df_o.to_csv(csv_file_path_overview, index=False)

def convert_kijiji_to_csv(all_unit_details,all_property_overviews,csv_file_path_details,csv_file_path_overview):
    #converting details data into csv
    df_details = pd.DataFrame.from_dict(all_unit_details, orient='index').reset_index().rename(columns={'index':'unit_id'})
    df_details.to_csv(csv_file_path_details, index=False)

    #converting overview data into csv
    df_o = pd.DataFrame.from_dict(all_property_overviews, orient='index').reset_index().rename(columns={'index':'unit_id'})
    df_o['description'] = df_o['description'].apply(lambda x: re.sub(r'[^A-Za-z0-9 ]+', '', x))
    df_o.to_csv(csv_file_path_overview, index=False)

# %%
# @title #### Convert list of URLs into CSV
def convert_to_csv(data, filename):
  # Open the file in write mode ('w') and create a csv.writer object
  count = 0
  with open(filename, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write each row to the CSV file
    for list_ in data:
      for link in list_:
        count += 1
        writer.writerow([link])

  print(f"CSV file '{filename}' created successfully. Number of Links: {count}")

# %% [markdown]
# ## Part 1: Getting your datasets from Web Scraping [Data Collection - Total 20 pts]
#
#
# **Objective**: Create 4 CSVs on the data scraped from Kijiji and RentFaster.
#
# For RentFaster, we have selected all cities/areas from AB. We can expand the search and include more provinces as need it but not required. You can select up to 25 locations across Alberta to get the listing data from Rent Faster.
#
# For Kijiji, we will be selecting listings from the following [URL](https://www.kijiji.ca/b-for-rent/alberta/page-1/c30349001l9003) and you can pick the number of listing pages you want to scrape links from. The total listing pages are 190. Each page contains 40 listings so you can get up to 7600 URLs from the website, but you are not required to get all the data.
#
#
# In order to get the 20 pts from this step you will need to perform the following:
#
# *   Select 1 major city (either Edmonton or Calgary) + 5 other locations. The total selected cities/areas need to be 6, which will be approximately 600+ listings. This can be done in **Step 1**
# *   Select 1 or up to 3 page ranges from **Step 2**. The total numbers generated by the ranges you picked CANNOT be more than 12. Here is an example of a proper range selection:
#
#     * range 1 = [20 - 25], range 2 = [9 - 11], range 3 = [3 - 5] -> Numbers generated [3, 4, 5, 9, 10, 11, 20, 21, 22, 23, 24, 25] Total of 12 page numbers
# *   Run cells from Step 3 to 9 to generate the CSVs from the data you scraped and follow the instructions

# %%
# @title ### Step 1: Alberta Location Selector - RentFaster
from ipywidgets import SelectMultiple, VBox, Label, Layout, Text
import ipywidgets as widgets

# Define your list of options for the multiple select widget
options = [
  'edmonton', 'calgary', 'cochrane', 'red-deer', 'fort-mcmurray',
  'airdrie', 'wetaskiwin', 'lethbridge', 'camrose', 'spruce-grove',
  'okotoks', 'chestermere', 'bonnyville', 'st-albert', 'sylvan-lake',
  'beaumont', 'morinville', 'leduc', 'grande-prairie', 'peace-river',
  'strathmore', 'edson', 'wainwright', 'olds','ponoka'
]

# Create a text widget for displaying selected options
selected_output = Text(
    value='',
    placeholder='Selected options will appear here',
    description='Selected:',
    disabled=False,
    layout=Layout(width='100%')
)

# Event handler function
def on_selection_change(change):
    if change['name'] == 'value':
        # Convert selected options to lowercase and update the text widget
        selected_options = ', '.join([option.lower() for option in change['new']])
        selected_output.value = selected_options

# Create the SelectMultiple widget
location_selector = SelectMultiple(
    options=options,
    value=[],  # No default selection
    description='Locations',
    disabled=False,
    layout=Layout(width='100%', height='200px')  # Adjust layout as needed
)

# Set up the event handler for changes in selection
location_selector.observe(on_selection_change, names='value')

# Instructions on how to select multiple options
instructions = Label('Hold down "Ctrl" (Windows/Linux) or "Cmd" (Mac) to select multiple locations.')

# Group the instructions, the select widget, and the selected output together
vbox = VBox([instructions, location_selector, selected_output])
display(vbox)
# Out:
# VBox(children=(Label(value='Hold down "Ctrl" (Windows/Linux) or "Cmd" (Mac) to select multiple locations.'), S…

# %%
#@title ### Step 2: Get URLs using the URL generator based on your selection
selected_locations = location_selector.value
if not selected_locations:
  print("Please make a selection (at least 1 city) to continue")
else:
  rent_faster_urls = await url_generator(selected_locations,False,True)
# Out:
# Getting listing URLs for edmonton [RentFaster]
# Getting listing URLs for red-deer [RentFaster]
# Getting listing URLs for lethbridge [RentFaster]
# Getting listing URLs for camrose [RentFaster]
# Getting listing URLs for spruce-grove [RentFaster]
# Getting listing URLs for st-albert [RentFaster]
# URLs retrieved

# %%
#@title ### Step 3: Convert list of URLs into CSV - RentFaster
import ipywidgets as widgets
from IPython.display import display, clear_output

output = widgets.Output()

# Text input widget for the filename
filename_input = widgets.Text(
    value='',
    placeholder='Enter filename here',
    description='Filename:',
    disabled=False
)

# Button to trigger the save action
save_button = widgets.Button(
    description='Save as CSV',
    disabled=False,
    button_style='',
    tooltip='Save your data as a CSV file',
)

# Label for instructions
instructions = widgets.HTML(
    value="If you want to save your data as a CSV run this cell and include the name of the file you want, "
          "please <strong>ONLY use letter and numbers</strong>."
)

def save_to_csv(b):
    with output:
        clear_output(wait=True)
        filename = filename_input.value
        # Validate filename: contains only letters and numbers
        if re.match("^[a-zA-Z0-9]+$", filename):  # Ensure filename is not empty and matches the criteria
            convert_to_csv(rent_faster_urls, f"{filename}.csv")  # Call the function with the provided filename
            print(f"Data saved successfully to {filename}.csv.")
        else:
            print("Error: Filename should only contain letters and numbers and cannot be empty.")

# Set the button click event handler
save_button.on_click(save_to_csv)

# Display the widgets
display(instructions, filename_input, save_button, output)
# Out:
# HTML(value='If you want to save your data as a CSV run this cell and include the name of the file you want, pl…
# Text(value='', description='Filename:', placeholder='Enter filename here')
# Button(description='Save as CSV', style=ButtonStyle(), tooltip='Save your data as a CSV file')
# Output()

# %%
# @title ### Step 4: Range Selector - Kijiji
from ipywidgets import IntRangeSlider, VBox, Button, Output, HTML
from IPython.display import display, clear_output

range_sliders = []  # List to keep track of range sliders
selected_ranges_output = Output()  # Widget to display the selected ranges and generated numbers
generated_numbers = []
# Using HTML widget instead of Label to incorporate line breaks for new lines
description_html = HTML(
    value="This code will help you select the listing numbers you want to retrieve data from Kijiji.<br>"
          "You can select up to 3 ranges from the selector"
          "Once a range has been selected, you would need to click on <strong>'Add New Range'</strong>.<br>"
          "After selecting all your ranges you would need to click on <strong>'Generate Numbers'</strong>. If you want to delete your selection, just clear the output of <strong>THIS CELL</strong> and run it again"
)
def add_range_slider(b=None):
    """Adds a new range slider to the list and updates the display."""
    if len(range_sliders) < 3:  # Limit to 3 range sliders
        new_range_slider = IntRangeSlider(
            value=[1, 10],
            min=1,
            max=190,
            step=1,
            description='Pick a range:',
            disabled=False,
            continuous_update=False,
            orientation='horizontal',
            readout=True
        )
        range_sliders.append(new_range_slider)
        update_display()
    else:
        with selected_ranges_output:
            clear_output(wait=True)  # Clear any previous output messages
            print("Maximum of 3 ranges reached.")

def collect_ranges_and_generate_numbers(b):
    """Collects ranges from sliders, generates numbers within those ranges, and displays the result."""
    with selected_ranges_output:
        clear_output(wait=True)  # Clear the previous output
        all_ranges = [slider.value for slider in range_sliders]
        for r in all_ranges:
            generated_numbers.extend(list(range(r[0], r[1] + 1)))  # Generate numbers within the range
        print("Selected ranges:", ', '.join([f"{r[0]}-{r[1]}" for r in all_ranges]))
        print("Generated numbers:", generated_numbers)

def update_display():
    """Updates the display with all widgets."""
    clear_output(wait=True)  # Clear the previous output including sliders
    display(description_html)  # Display the instructions with HTML for line breaks
    for slider in range_sliders:
        display(slider)
    display(add_range_btn)
    display(collect_ranges_btn)
    display(selected_ranges_output)

# Button to add a new range slider
add_range_btn = Button(description='Add New Range')
add_range_btn.on_click(add_range_slider)

# Button to collect ranges and generate numbers
collect_ranges_btn = Button(description='Generate Numbers')
collect_ranges_btn.on_click(collect_ranges_and_generate_numbers)

# Initial call to add the first range slider and display everything
add_range_slider()

# Initially display the widgets
update_display()
# Out:
# HTML(value="This code will help you select the listing numbers you want to retrieve data from Kijiji.<br>You c…
# IntRangeSlider(value=(52, 55), continuous_update=False, description='Pick a range:', max=190, min=1)
# IntRangeSlider(value=(1, 10), continuous_update=False, description='Pick a range:', max=190, min=1)
# Button(description='Add New Range', style=ButtonStyle())
# Button(description='Generate Numbers', style=ButtonStyle())
# Output()

# %%
# @title ### Step 5: Get URLs using the URL generator based on your page range selection
# @markdown Now that we have the ranges selected we will scrape the URLs from each page in the listing within the Kijiji website. **Run this cell**

if not generated_numbers:
  print("Please make a selection (at least 1 city) to continue")
else:
  kijiji_urls = await url_generator(generated_numbers,True,False)
# Out:
# Getting listing URLs for AB page 52 [Kijiji]
# Getting listing URLs for AB page 53 [Kijiji]
# Getting listing URLs for AB page 54 [Kijiji]
# Attempt 1 failed with error Page.wait_for_selector: Timeout 6000ms exceeded.
# Call log:
# waiting for locator("ul[data-testid=\"srp-search-list\"]") to be visible
#   -   locator resolved to 2 elements. Proceeding with the first one: <ul class="sc-68931dd3-0 dFkkEs" data-testid="srp-se…>…</ul>
# , retrying...
# Getting listing URLs for AB page 55 [Kijiji]
# Attempt 1 failed with error Page.wait_for_selector: Timeout 6000ms exceeded.
# Call log:
# waiting for locator("ul[data-testid=\"srp-search-list\"]") to be visible
#   -   locator resolved to 2 elements. Proceeding with the first one: <ul class="sc-68931dd3-0 dFkkEs" data-testid="srp-se…>…</ul>
# , retrying...
# Getting listing URLs for AB page 57 [Kijiji]
# Attempt 1 failed with error Page.goto: Timeout 30000ms exceeded.
# Call log:
# navigating to "https://www.kijiji.ca/b-for-rent/alberta/page-57/c30349001l9003", waiting until "load"
# , retrying...
# Getting listing URLs for AB page 58 [Kijiji]
# Attempt 1 failed with error Page.goto: Timeout 30000ms exceeded.
# Call log:
# navigating to "https://www.kijiji.ca/b-for-rent/alberta/page-58/c30349001l9003", waiting until "load"
# , retrying...
# Getting listing URLs for AB page 59 [Kijiji]
# Getting listing URLs for AB page 60 [Kijiji]
# Getting listing URLs for AB page 61 [Kijiji]
# URLs retrieved

# %%
# @title ### Step 6: Convert list of URLs into CSV - Kijiji
import ipywidgets as widgets
from IPython.display import display, clear_output
output = widgets.Output()

# Text input widget for the filename
filename_input = widgets.Text(
    value='',
    placeholder='Enter filename here',
    description='Filename:',
    disabled=False
)

# Button to trigger the save action
save_button = widgets.Button(
    description='Save as CSV',
    disabled=False,
    button_style='',
    tooltip='Save your data as a CSV file',
)

# Label for instructions
instructions = widgets.HTML(
    value="If will need to save your URLs data as a CSV, please run this cell and include the name of the file you want, "
          "<strong>ONLY use letter and numbers</strong>."
)

def save_to_csv(b):
    with output:
        clear_output(wait=True)
        filename = filename_input.value
        # Validate filename: contains only letters and numbers
        if re.match("^[a-zA-Z0-9]+$", filename):  # Ensure filename is not empty and matches the criteria
            convert_to_csv(kijiji_urls, f"{filename}.csv")  # Call the function with the provided filename
            print(f"Data saved successfully to {filename}.csv.")
        else:
            print("Error: Filename should only contain letters and numbers and cannot be empty.")

# Set the button click event handler
save_button.on_click(save_to_csv)

# Display the widgets
display(instructions, filename_input, save_button, output)
# Out:
# HTML(value='If will need to save your URLs data as a CSV, please run this cell and include the name of the fil…
# Text(value='', description='Filename:', placeholder='Enter filename here')
# Button(description='Save as CSV', style=ButtonStyle(), tooltip='Save your data as a CSV file')
# Output()

# %% [markdown]
# **Important NOTE**
#
# Because we are dealing with 2 datasets (Kijiji and RentFaster) you will need to perform the following steps in this order:
#
# 1. Select csv with URLs from either Kijiji or RentFaster (Step 7)
# 2. Initialize variables (Step 7.1)
# 3. Perform the scraping on the selected data (Step 8)
# 4. Saved the craped data (Step 9)
#
# After you have done it once for either Kijiji or RentFaster, you will need to do perform the following steps in this order:
#
# 1. Select csv with URLs from either Kijiji or RentFaster (Step 7)
# 2. Perform the scraping on the selected data (Step 8)
# 3. Saved the craped data (Step 9)
#
# **DO NOT PERFORM** step 7.1 again as it will delete your data. Remember to download in your computer the generated CSV files to have a backup!

# %%
# @title ### Step 7: Select CSV and Website
# @markdown Please select the name of the file you have the URLs saved (from Step 6), it should be in CSV format. You also need to select the website of the URLs either Kijiji or RentFaster. After you have made your selection **you need to run this cell**

# @markdown ---
# @markdown #### Enter a file name:
file_name = "Runfasterlinks.csv" # @param {type:"string"}
# @markdown ---
# @markdown #### Enter the website name:
website = 'rentfaster' # @param ["kijiji","rentfaster"]

# %%
# @title ##### Step 7.1: Initialize/Reset global variables
# @markdown Initialize or **Reset** the following variables: `all_property_overviews_kk`, `all_unit_details_kk` for **Kijiji** and `all_property_overviews`, `all_unit_details` for **RentFaster**

# @markdown Run once to create the variables, if you run it again it will reset the variables **Use with caution as you MIGHT LOSS YOUR DATA**
all_property_overviews_kk = {}
all_unit_details_kk = {}
all_property_overviews = {}
all_unit_details = {}

# %%
# @title ### Step 8: Scrape the URLs
# @markdown Execute this cell to Scrape and Parse URLs from CSV you selected on Step 7. The results from the parsing will be saved in the following variables: `all_property_overviews_kk`, `all_unit_details_kk` for **Kijiji** and `all_property_overviews`, `all_unit_details` for **RentFaster**
try:
  await scrape_urls_from_csv(file_name,website)
  back_up_overviews.update(all_property_overviews_kk)
  back_up_overviews.update(all_property_overviews)
  back_up_details.update(all_unit_details)
  back_up_details.update(all_unit_details_kk)
except:
  print("Please run the steps above to select a file name and website")
# Out:
# URLs extracted from the CSV file: Runfasterlinks.csv. Total URLs to scrape: 741
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/queen-mary-park/pet-friendly/554875. [1/741]
# Scraped 1 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/griesbach/pet-friendly/540024. [2/741]
# Scraped 2 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/mckernan/pet-friendly/549526. [3/741]
# Scraped 3 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/sherwood-park/rentals/apartment/2-bedrooms/pet-friendly/561691. [4/741]
# Scraped 4 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/478927. [5/741]
# Scraped 5 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/433936. [6/741]
# Scraped 6 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/517036. [7/741]
# Scraped 7 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/437717. [8/741]
# Scraped 8 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/433937. [9/741]
# Scraped 9 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/old-strathcona/pet-friendly/557148. [10/741]
# Scraped 10 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/ermineskin/pet-friendly/524792. [11/741]
# Scraped 11 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/old-strathcona/pet-friendly/437811. [12/741]
# Scraped 12 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/377693. [13/741]
# Scraped 13 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/cromdale/pet-friendly/478186. [14/741]
# Scraped 14 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/tamarack/pet-friendly/419725. [15/741]
# Scraped 15 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/charlesworth/pet-friendly/454900. [16/741]
# Scraped 16 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/overlanders/pet-friendly/455310. [17/741]
# Scraped 17 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/alberta-avenue/pet-friendly/313667. [18/741]
# No valid JSON data found for the provided listing. Skipping Listing
# Scraped 18 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/overlanders/pet-friendly/455314. [19/741]
# Scraped 19 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/255055. [20/741]
# Scraped 20 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/overlanders/pet-friendly/455313. [21/741]
# Scraped 21 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/killarney/pet-friendly/358143. [22/741]
# Scraped 22 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/garneau/pet-friendly/552098. [23/741]
# Scraped 23 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/strathcona/furnished/532440. [24/741]
# Scraped 24 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/493941. [25/741]
# Scraped 25 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/tamarack/pet-friendly/562748. [26/741]
# Scraped 26 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/queen-alexandra/pet-friendly/554010. [27/741]
# Scraped 27 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/554878. [28/741]
# Scraped 28 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/queen-mary-park/pet-friendly/354691. [29/741]
# Scraped 29 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/413251. [30/741]
# Scraped 30 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/sherwood-park/rentals/apartment/1-bedroom/pet-friendly/370057. [31/741]
# Scraped 31 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/oliver/pet-friendly/418391. [32/741]
# Scraped 32 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/windermere/pet-friendly/538187. [33/741]
# Scraped 33 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/1-bedroom/westmount/pet-friendly/518094. [34/741]
# Scraped 34 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/empire-park/pet-friendly/455427. [35/741]
# Scraped 35 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/secord/pet-friendly/550991. [36/741]
# Scraped 36 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/paisley/pet-friendly/540915. [37/741]
# Scraped 37 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/canon-ridge/pet-friendly/456596. [38/741]
# Scraped 38 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/460758. [39/741]
# Scraped 39 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/eastwood/pet-friendly/334156. [40/741]
# Scraped 40 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/overlanders/pet-friendly/456767. [41/741]
# Scraped 41 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/elmwood-park/pet-friendly/334286. [42/741]
# Scraped 42 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/empire-park/pet-friendly/478152. [43/741]
# Scraped 43 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/empire-park/pet-friendly/455425. [44/741]
# Scraped 44 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/470242. [45/741]
# Scraped 45 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/empire-park/pet-friendly/478151. [46/741]
# Scraped 46 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/canora/pet-friendly/334147. [47/741]
# Scraped 47 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/sherbrooke/pet-friendly/334141. [48/741]
# Scraped 48 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/queen-mary-park/pet-friendly/402270. [49/741]
# Scraped 49 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/overlanders/pet-friendly/455312. [50/741]
# Scraped 50 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/529631. [51/741]
# Scraped 51 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/boyle-street/non-smoking/294096. [52/741]
# Scraped 52 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/empire-park/pet-friendly/455426. [53/741]
# Scraped 53 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/queen-mary/pet-friendly/289360. [54/741]
# Scraped 54 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/hollick-kenyon/pet-friendly/538188. [55/741]
# Scraped 55 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/mckernan/pet-friendly/554977. [56/741]
# Scraped 56 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/old-strathcona/pet-friendly/273131. [57/741]
# Scraped 57 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/360187. [58/741]
# Scraped 58 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/476157. [59/741]
# Scraped 59 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/1-bedroom/pet-friendly/532122. [60/741]
# Scraped 60 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/1-bedroom/grovenor/pet-friendly/556454. [61/741]
# Scraped 61 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/1-bedroom/bonnie-doon/pet-friendly/555428. [62/741]
# Scraped 62 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/565124. [63/741]
# Scraped 63 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/charlesworth/pet-friendly/468424. [64/741]
# Scraped 64 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/heritage-valley/pet-friendly/564458. [65/741]
# Scraped 65 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/403321. [66/741]
# Scraped 66 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/walterdale/pet-friendly/288628. [67/741]
# Scraped 67 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/parkdale/pet-friendly/565047. [68/741]
# Scraped 68 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/strathcona/non-smoking/412759. [69/741]
# Scraped 69 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/aldergrove/pet-friendly/335068. [70/741]
# Scraped 70 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/gold-bar/pet-friendly/263032. [71/741]
# Scraped 71 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/empire-park/pet-friendly/263030. [72/741]
# Scraped 72 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/garneau/pet-friendly/263034. [73/741]
# Scraped 73 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/262969. [74/741]
# Scraped 74 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/boyle-street/pet-friendly/564453. [75/741]
# Scraped 75 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/empire-park/pet-friendly/262970. [76/741]
# Scraped 76 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/garneau/pet-friendly/530057. [77/741]
# Scraped 77 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/ermineskin/pet-friendly/466212. [78/741]
# Scraped 78 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/youngstown/502856. [79/741]
# Scraped 79 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/empire-park/pet-friendly/263041. [80/741]
# Scraped 80 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/rossdale/pet-friendly/433938. [81/741]
# Scraped 81 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/empire-park/pet-friendly/262888. [82/741]
# Scraped 82 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/garneau/pet-friendly/523496. [83/741]
# Scraped 83 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/allard/pet-friendly/301691. [84/741]
# Scraped 84 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/ermineskin/pet-friendly/466211. [85/741]
# Scraped 85 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/non-smoking/450160. [86/741]
# Scraped 86 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/non-smoking/433944. [87/741]
# Scraped 87 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/cromdale/pet-friendly/478189. [88/741]
# Scraped 88 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/ramsay-heights/pet-friendly/559561. [89/741]
# Scraped 89 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/homesteader/pet-friendly/563168. [90/741]
# Scraped 90 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/sherwood-park/rentals/apartment/1-bedroom/pet-friendly/300068. [91/741]
# Scraped 91 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/macewan/pet-friendly/358171. [92/741]
# Scraped 92 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/homesteader/pet-friendly/546595. [93/741]
# Scraped 93 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/boyle-street/502853. [94/741]
# Scraped 94 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/garneau/pet-friendly/477780. [95/741]
# Scraped 95 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/sweet-grass/pet-friendly/553321. [96/741]
# Scraped 96 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/garneau/furnished/558247. [97/741]
# Scraped 97 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/564448. [98/741]
# Scraped 98 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/560864. [99/741]
# Scraped 99 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/killarney/pet-friendly/508370. [100/741]
# Scraped 100 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/strathcona/pet-friendly/534789. [101/741]
# Scraped 101 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/508373. [102/741]
# Scraped 102 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/hollick-kenyon/pet-friendly/300071. [103/741]
# Scraped 103 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/non-smoking/450159. [104/741]
# Scraped 104 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/oliver/non-smoking/450153. [105/741]
# Scraped 105 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/york/non-smoking/450155. [106/741]
# Scraped 106 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/5-bedrooms/rio-terrace/463222. [107/741]
# Scraped 107 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/garneau/pet-friendly/437712. [108/741]
# Scraped 108 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/richfield/non-smoking/450156. [109/741]
# Scraped 109 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/queen-alexandra/554793. [110/741]
# Scraped 110 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/queen-mary-park/non-smoking/541925. [111/741]
# Scraped 111 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/queen-mary-park/pet-friendly/495803. [112/741]
# Scraped 112 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/2-bedrooms/pet-friendly/454505. [113/741]
# Scraped 113 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/boyle-street/pet-friendly/454506. [114/741]
# Scraped 114 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/garneau/short-term/523497. [115/741]
# Scraped 115 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/tamarack/pet-friendly/340737. [116/741]
# Scraped 116 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/tamarack/pet-friendly/340736. [117/741]
# Scraped 117 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/tamarack/pet-friendly/505023. [118/741]
# Scraped 118 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/sherwood-park/rentals/apartment/1-bedroom/pet-friendly/514202. [119/741]
# Scraped 119 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/jackson-heights/pet-friendly/344534. [120/741]
# Scraped 120 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/sherwood-park/rentals/apartment/1-bedroom/pet-friendly/504369. [121/741]
# Scraped 121 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/477790. [122/741]
# Scraped 122 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/glenridding-ravine/pet-friendly/543924. [123/741]
# Scraped 123 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/downtown/pet-friendly/510464. [124/741]
# Scraped 124 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/graydon-hill/pet-friendly/340735. [125/741]
# Scraped 125 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/477775. [126/741]
# Scraped 126 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/412229. [127/741]
# Scraped 127 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/callingwood/pet-friendly/508376. [128/741]
# Scraped 128 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/1-bedroom/walker/pet-friendly/482131. [129/741]
# Scraped 129 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/strathcona/non-smoking/513451. [130/741]
# Scraped 130 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/glenwood/pet-friendly/564910. [131/741]
# Scraped 131 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/greenfield/pet-friendly/388292. [132/741]
# Scraped 132 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/rosslyn/pet-friendly/562478. [133/741]
# Scraped 133 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/rosenthal/pet-friendly/561987. [134/741]
# Scraped 134 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/crystallina-nera/non-smoking/535178. [135/741]
# Scraped 135 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/4-bedrooms/glenridding-ravine/pet-friendly/564329. [136/741]
# Scraped 136 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/downtown/furnished/302746. [137/741]
# Scraped 137 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/cloverdale/pet-friendly/565483. [138/741]
# Scraped 138 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/orchards/non-smoking/565529. [139/741]
# Scraped 139 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/2-bedrooms/avonmore/pet-friendly/563026. [140/741]
# Scraped 140 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/tipaskan/pet-friendly/288682. [141/741]
# Scraped 141 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/mcdougall/pet-friendly/560275. [142/741]
# Scraped 142 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/shared/1-bedroom/mckernan/furnished/317127. [143/741]
# Scraped 143 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/balwin/pet-friendly/557877. [144/741]
# Scraped 144 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/mill-woods/non-smoking/565011. [145/741]
# Scraped 145 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/glenora/non-smoking/340874. [146/741]
# Scraped 146 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/belmead/pet-friendly/545126. [147/741]
# Scraped 147 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/secord/pet-friendly/466024. [148/741]
# Scraped 148 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/3-bedrooms/cromdale/pet-friendly/334154. [149/741]
# Scraped 149 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/strathcona/pet-friendly/565521. [150/741]
# Scraped 150 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/oliver/non-smoking/563765. [151/741]
# Scraped 151 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/downtown/non-smoking/287908. [152/741]
# Scraped 152 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/4-bedrooms/secord/pet-friendly/513891. [153/741]
# Scraped 153 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/idylwylde/pet-friendly/522642. [154/741]
# Scraped 154 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/fulton-place/pet-friendly/334235. [155/741]
# Scraped 155 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/oliver/non-smoking/558785. [156/741]
# Scraped 156 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/4-bedrooms/greenfield/pet-friendly/560649. [157/741]
# Scraped 157 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/queen-mary-park/pet-friendly/470341. [158/741]
# Scraped 158 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/oliver/pet-friendly/560623. [159/741]
# Scraped 159 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/walker/non-smoking/526442. [160/741]
# Scraped 160 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/shared/2-bedrooms/kilkenny/furnished/563170. [161/741]
# Scraped 161 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/walker/pet-friendly/469675. [162/741]
# Scraped 162 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/secord/non-smoking/559989. [163/741]
# Scraped 163 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/glenridding-ravine/non-smoking/565659. [164/741]
# Scraped 164 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/blatchford/non-smoking/503712. [165/741]
# Scraped 165 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/secord/pet-friendly/466019. [166/741]
# Scraped 166 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/aurora/non-smoking/565306. [167/741]
# Scraped 167 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/downtown/pet-friendly/282626. [168/741]
# Scraped 168 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/ellerslie/pet-friendly/565527. [169/741]
# Scraped 169 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/1-bedroom/downtown/furnished/470312. [170/741]
# Scraped 170 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/1-bedroom/calder/non-smoking/558110. [171/741]
# Scraped 171 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/beverly-heights/furnished/565308. [172/741]
# Scraped 172 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/basement/2-bedrooms/non-smoking/565225. [173/741]
# Scraped 173 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/oliver/non-smoking/282248. [174/741]
# Scraped 174 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/baturyn/non-smoking/563628. [175/741]
# Scraped 175 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/homesteader/pet-friendly/565165. [176/741]
# Scraped 176 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/callingwood/furnished/490790. [177/741]
# Scraped 177 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/woodcroft/pet-friendly/415566. [178/741]
# Scraped 178 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/6-bedrooms/crestwood/pet-friendly/537985. [179/741]
# Scraped 179 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/2-bedrooms/pet-friendly/547687. [180/741]
# Scraped 180 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/garneau/non-smoking/268308. [181/741]
# Scraped 181 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/1-bedroom/calder/non-smoking/559568. [182/741]
# Scraped 182 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/rutherford/non-smoking/565404. [183/741]
# Scraped 183 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/2-bedrooms/bonnie-doon/non-smoking/449888. [184/741]
# Scraped 184 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/queen-mary-park/pet-friendly/513576. [185/741]
# Scraped 185 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/studio/calder/non-smoking/558109. [186/741]
# Scraped 186 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/shared/1-bedroom/beverly-heights/furnished/564725. [187/741]
# Scraped 187 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/ermineskin/pet-friendly/288668. [188/741]
# Scraped 188 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/sherwood-park/rentals/duplex/2-bedrooms/pet-friendly/565195. [189/741]
# Scraped 189 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/strathcona/non-smoking/539755. [190/741]
# Scraped 190 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/3-bedrooms/stillwater/pet-friendly/565068. [191/741]
# Scraped 191 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/clareview/564005. [192/741]
# Scraped 192 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/belgravia/pet-friendly/565510. [193/741]
# Scraped 193 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/studio/calder/non-smoking/558112. [194/741]
# Scraped 194 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/2-bedrooms/canossa/pet-friendly/557788. [195/741]
# Scraped 195 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/canora/pet-friendly/260207. [196/741]
# Scraped 196 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/mcconachie/furnished/564820. [197/741]
# Scraped 197 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/419913. [198/741]
# Scraped 198 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/alberta-avenue/526418. [199/741]
# Scraped 199 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/calder/non-smoking/558098. [200/741]
# Scraped 200 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/the-uplands/non-smoking/564379. [201/741]
# Scraped 201 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/canora/pet-friendly/334148. [202/741]
# Scraped 202 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/orchards/non-smoking/563779. [203/741]
# Scraped 203 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/meadows/non-smoking/561100. [204/741]
# Scraped 204 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/blackmud-creek/non-smoking/339428. [205/741]
# Scraped 205 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/glenwood/pet-friendly/563763. [206/741]
# Scraped 206 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/mcconachie/non-smoking/516486. [207/741]
# Scraped 207 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/tamarack/non-smoking/565526. [208/741]
# Scraped 208 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/glenwood/pet-friendly/382302. [209/741]
# Scraped 209 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/529799. [210/741]
# Scraped 210 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/glenridding-heights/pet-friendly/564377. [211/741]
# Scraped 211 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/meadowlark-park/pet-friendly/478571. [212/741]
# Scraped 212 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/downtown/pet-friendly/448909. [213/741]
# Scraped 213 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/1-bedroom/strathcona/non-smoking/280243. [214/741]
# Scraped 214 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/3-bedrooms/queen-alexandra/non-smoking/511362. [215/741]
# Scraped 215 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/kildare/pet-friendly/270900. [216/741]
# Scraped 216 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/queen-mary-park/pet-friendly/477024. [217/741]
# Scraped 217 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/strathcona/pet-friendly/491320. [218/741]
# Scraped 218 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/mcdougall/pet-friendly/288660. [219/741]
# Scraped 219 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/casselman/pet-friendly/545125. [220/741]
# Scraped 220 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/3-bedrooms/charlesworth/short-term/565285. [221/741]
# Scraped 221 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/288623. [222/741]
# Scraped 222 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/mcdougall/pet-friendly/370060. [223/741]
# Scraped 223 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/mcdougall/pet-friendly/370061. [224/741]
# Scraped 224 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/hollick-kenyon/non-smoking/500915. [225/741]
# Scraped 225 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/montrose/pet-friendly/565178. [226/741]
# Scraped 226 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/caernarvon/pet-friendly/288649. [227/741]
# Scraped 227 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/5-bedrooms/mayliewan/565180. [228/741]
# Scraped 228 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/lansdowne/pet-friendly/288684. [229/741]
# Scraped 229 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/mcdougall/non-smoking/564788. [230/741]
# Scraped 230 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/2-bedrooms/alberta-avenue/pet-friendly/561152. [231/741]
# Scraped 231 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/1-bedroom/chappelle/pet-friendly/533589. [232/741]
# No valid JSON data found for the provided listing. Skipping Listing
# Scraped 232 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/3-bedrooms/ritchie/pet-friendly/461623. [233/741]
# Scraped 233 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/furnished/311208. [234/741]
# No valid JSON data found for the provided listing. Skipping Listing
# Scraped 234 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/6-bedrooms/bonnie-doon/non-smoking/495494. [235/741]
# Scraped 235 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/storage/non-smoking/411812. [236/741]
# Scraped 236 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/downtown/pet-friendly/565253. [237/741]
# Scraped 237 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/shared/5-bedrooms/mckernan/furnished/527269. [238/741]
# Scraped 238 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/king-edward-park/pet-friendly/563987. [239/741]
# Scraped 239 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/shared/3-bedrooms/boyle-street/short-term/565119. [240/741]
# Scraped 240 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/555626. [241/741]
# Scraped 241 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/studio/oliver/non-smoking/556315. [242/741]
# Scraped 242 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/tweddle-place/pet-friendly/288667. [243/741]
# Scraped 243 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/downtown/pet-friendly/563406. [244/741]
# No valid JSON data found for the provided listing. Skipping Listing
# Scraped 244 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/parkdale/pet-friendly/494332. [245/741]
# Scraped 245 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/west-jasper-place/pet-friendly/518958. [246/741]
# Scraped 246 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/studio/westwood/non-smoking/491427. [247/741]
# Scraped 247 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/sherwood-park/rentals/house/4-bedrooms/pet-friendly/523789. [248/741]
# Scraped 248 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/shared/4-bedrooms/garneau/furnished/506754. [249/741]
# Scraped 249 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/queen-alexandra/pet-friendly/560121. [250/741]
# Scraped 250 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/rutherford/non-smoking/557860. [251/741]
# Scraped 251 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/strathcona/pet-friendly/504393. [252/741]
# Scraped 252 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/2-bedrooms/sherwood/pet-friendly/473284. [253/741]
# Scraped 253 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/glenridding-ravine/pet-friendly/565217. [254/741]
# Scraped 254 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/queen-mary-park/pet-friendly/557407. [255/741]
# Scraped 255 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/downtown/non-smoking/522397. [256/741]
# Scraped 256 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/heritage-valley/pet-friendly/528883. [257/741]
# Scraped 257 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/4-bedrooms/blue-quill-estates/pet-friendly/563907. [258/741]
# Scraped 258 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/rosenthal/pet-friendly/565103. [259/741]
# No valid JSON data found for the provided listing. Skipping Listing
# Scraped 259 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/garneau/pet-friendly/536670. [260/741]
# Scraped 260 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/3-bedrooms/glengarry/pet-friendly/557389. [261/741]
# Scraped 261 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/alberta-avenue/pet-friendly/487256. [262/741]
# Scraped 262 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/downtown/pet-friendly/528755. [263/741]
# Scraped 263 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/condo/2-bedrooms/pet-friendly/549227. [264/741]
# Scraped 264 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/strathcona/non-smoking/462083. [265/741]
# Scraped 265 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/555746. [266/741]
# Scraped 266 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/3-bedrooms/king-edward-park/non-smoking/554487. [267/741]
# Scraped 267 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/sherwood-park/rentals/duplex/2-bedrooms/pet-friendly/565171. [268/741]
# Scraped 268 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/oliver/non-smoking/563817. [269/741]
# Scraped 269 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/hamptons/pet-friendly/565080. [270/741]
# Scraped 270 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/sherwood/non-smoking/561823. [271/741]
# Scraped 271 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/glenwood/pet-friendly/563955. [272/741]
# Scraped 272 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/4-bedrooms/the-uplands/non-smoking/561783. [273/741]
# Scraped 273 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/504939. [274/741]
# Scraped 274 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/grovenor/pet-friendly/560327. [275/741]
# Scraped 275 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/blatchford/pet-friendly/541246. [276/741]
# Scraped 276 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/callingwood/pet-friendly/565174. [277/741]
# Scraped 277 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/3-bedrooms/boyle-street/non-smoking/549143. [278/741]
# Scraped 278 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/heritage-valley/non-smoking/561458. [279/741]
# Scraped 279 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/sherbrooke/pet-friendly/543050. [280/741]
# Scraped 280 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/oliver/461509. [281/741]
# Scraped 281 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/queen-mary-park/pet-friendly/564975. [282/741]
# Scraped 282 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/heritage-valley/non-smoking/546968. [283/741]
# Scraped 283 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/montrose/pet-friendly/494829. [284/741]
# Scraped 284 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/mayfield/furnished/564864. [285/741]
# Scraped 285 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/3-bedrooms/summerside/pet-friendly/562009. [286/741]
# Scraped 286 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/oliver/non-smoking/560154. [287/741]
# Scraped 287 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/downtown/pet-friendly/451941. [288/741]
# Scraped 288 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/downtown/pet-friendly/490599. [289/741]
# Scraped 289 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/1-bedroom/cavanagh/furnished/564980. [290/741]
# Scraped 290 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/belvedere/pet-friendly/564921. [291/741]
# Scraped 291 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/2-bedrooms/summerside/pet-friendly/562000. [292/741]
# Scraped 292 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/highlands/pet-friendly/483177. [293/741]
# Scraped 293 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/terra-losa/non-smoking/522981. [294/741]
# Scraped 294 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/sherwood-park/rentals/apartment/1-bedroom/pet-friendly/470748. [295/741]
# Scraped 295 urls out of 741 total.
# ...
# Scraped 642 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/basement/2-bedrooms/non-smoking/548457. [643/741]
# Scraped 643 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/basement/2-bedrooms/non-smoking/565225. [644/741]
# Scraped 644 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/2-bedrooms/pet-friendly/547687. [645/741]
# Scraped 645 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/1-bedroom/calder/non-smoking/559568. [646/741]
# Scraped 646 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/studio/calder/non-smoking/558112. [647/741]
# Scraped 647 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/calder/non-smoking/558098. [648/741]
# Scraped 648 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/1-bedroom/calder/non-smoking/558110. [649/741]
# Scraped 649 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/2-bedrooms/canossa/pet-friendly/557788. [650/741]
# Scraped 650 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/baturyn/non-smoking/563628. [651/741]
# Scraped 651 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/studio/calder/non-smoking/558109. [652/741]
# Scraped 652 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/storage/non-smoking/411812. [653/741]
# Scraped 653 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/caernarvon/pet-friendly/288649. [654/741]
# Scraped 654 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/blatchford/pet-friendly/541246. [655/741]
# Scraped 655 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/condo/2-bedrooms/pet-friendly/549227. [656/741]
# Scraped 656 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/sherbrooke/pet-friendly/543050. [657/741]
# Scraped 657 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/310183. [658/741]
# Scraped 658 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/kinglet-gardens/pet-friendly/561128. [659/741]
# Scraped 659 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/starling/pet-friendly/562593. [660/741]
# Scraped 660 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/334150. [661/741]
# Scraped 661 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/4-bedrooms/cumberland/non-smoking/435577. [662/741]
# Scraped 662 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/hudson/pet-friendly/558608. [663/741]
# Scraped 663 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/condo/3-bedrooms/non-smoking/564197. [664/741]
# Scraped 664 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/calder/non-smoking/536015. [665/741]
# Scraped 665 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/366459. [666/741]
# Scraped 666 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/main-floor/3-bedrooms/pet-friendly/563175. [667/741]
# Scraped 667 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/dovercourt/pet-friendly/562847. [668/741]
# Scraped 668 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/house/6-bedrooms/non-smoking/439590. [669/741]
# Scraped 669 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/griesbach/pet-friendly/537244. [670/741]
# Scraped 670 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/twin-brooks/pet-friendly/558857. [671/741]
# Scraped 671 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/dunluce/pet-friendly/289370. [672/741]
# Scraped 672 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/albany/pet-friendly/471353. [673/741]
# Scraped 673 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/shared/3-bedrooms/baturyn/non-smoking/561738. [674/741]
# Scraped 674 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/2-bedrooms/non-smoking/371395. [675/741]
# Scraped 675 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/carlton/non-smoking/299888. [676/741]
# Scraped 676 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/townhouse/2-bedrooms/pet-friendly/434619. [677/741]
# Scraped 677 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/sherbrooke/pet-friendly/420471. [678/741]
# Scraped 678 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/289412. [679/741]
# Scraped 679 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/289351. [680/741]
# Scraped 680 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/289263. [681/741]
# Scraped 681 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/294097. [682/741]
# Scraped 682 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/289403. [683/741]
# Scraped 683 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/kensington/pet-friendly/289324. [684/741]
# Scraped 684 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/wellington/pet-friendly/402727. [685/741]
# Scraped 685 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/2-bedrooms/sherbrooke/pet-friendly/289291. [686/741]
# Scraped 686 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/334224. [687/741]
# Scraped 687 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/inglewood/pet-friendly/334212. [688/741]
# Scraped 688 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/wellington/pet-friendly/365947. [689/741]
# Scraped 689 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/3-bedrooms/calder/short-term/261284. [690/741]
# No valid JSON data found for the provided listing. Skipping Listing
# Scraped 690 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/prince-charles/pet-friendly/538151. [691/741]
# Scraped 691 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/blatchford/non-smoking/527983. [692/741]
# Scraped 692 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/shared/1-bedroom/furnished/517092. [693/741]
# Scraped 693 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/1-bedroom/pet-friendly/518193. [694/741]
# Scraped 694 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/2-bedrooms/pet-friendly/338071. [695/741]
# Scraped 695 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/dunluce/pet-friendly/288672. [696/741]
# Scraped 696 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/1-bedroom/inglewood/non-smoking/565198. [697/741]
# Scraped 697 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/athlone/pet-friendly/288644. [698/741]
# Scraped 698 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/2-bedrooms/pet-friendly/289578. [699/741]
# Scraped 699 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/2-bedrooms/pet-friendly/288140. [700/741]
# Scraped 700 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/chambery/pet-friendly/391988. [701/741]
# Scraped 701 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/carlisle/non-smoking/563255. [702/741]
# Scraped 702 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/kensington/pet-friendly/563653. [703/741]
# Scraped 703 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/starling/non-smoking/549419. [704/741]
# Scraped 704 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/castle-down/non-smoking/515081. [705/741]
# Scraped 705 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/4-bedrooms/dunluce/non-smoking/565118. [706/741]
# Scraped 706 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/2-bedrooms/pet-friendly/479450. [707/741]
# Scraped 707 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/shared/1-bedroom/dovercourt/furnished/526907. [708/741]
# Scraped 708 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/shared/1-bedroom/furnished/512920. [709/741]
# Scraped 709 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/sherbrooke/pet-friendly/483773. [710/741]
# Scraped 710 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/house/3-bedrooms/pet-friendly/564543. [711/741]
# Scraped 711 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/5-bedrooms/oxford/pet-friendly/375897. [712/741]
# Scraped 712 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/house/5-bedrooms/calder/non-smoking/564534. [713/741]
# Scraped 713 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/kensington/pet-friendly/440778. [714/741]
# Scraped 714 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/basement/2-bedrooms/non-smoking/503262. [715/741]
# Scraped 715 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/basement/2-bedrooms/non-smoking/561400. [716/741]
# Scraped 716 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/1-bedroom/furnished/485946. [717/741]
# Scraped 717 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/basement/2-bedrooms/non-smoking/532001. [718/741]
# Scraped 718 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/basement/2-bedrooms/non-smoking/559796. [719/741]
# Scraped 719 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/oxford/pet-friendly/302849. [720/741]
# Scraped 720 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/townhouse/3-bedrooms/starling/non-smoking/560817. [721/741]
# Scraped 721 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/queen-mary-park/non-smoking/564880. [722/741]
# Scraped 722 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/2-bedrooms/dunluce/pet-friendly/288678. [723/741]
# Scraped 723 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/wellington/pet-friendly/541281. [724/741]
# Scraped 724 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/3-bedrooms/calder/non-smoking/481382. [725/741]
# Scraped 725 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/condo/2-bedrooms/blatchford/non-smoking/565310. [726/741]
# Scraped 726 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/blatchford/non-smoking/565461. [727/741]
# Scraped 727 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/blatchford/non-smoking/565307. [728/741]
# Scraped 728 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/starling/pet-friendly/565328. [729/741]
# Scraped 729 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/house/4-bedrooms/pet-friendly/442164. [730/741]
# Scraped 730 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/2-bedrooms/blatchford/non-smoking/539850. [731/741]
# Scraped 731 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/apartment/2-bedrooms/pet-friendly/274128. [732/741]
# Scraped 732 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/main-floor/3-bedrooms/dovercourt/pet-friendly/561140. [733/741]
# Scraped 733 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/duplex/3-bedrooms/trumpeter/non-smoking/361316. [734/741]
# Scraped 734 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/carlisle/pet-friendly/288674. [735/741]
# Scraped 735 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/prince-charles/furnished/561647. [736/741]
# Scraped 736 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/townhouse/3-bedrooms/pet-friendly/517307. [737/741]
# Scraped 737 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/basement/1-bedroom/prince-charles/non-smoking/522677. [738/741]
# Scraped 738 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/house/3-bedrooms/non-smoking/563391. [739/741]
# Scraped 739 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/st-albert/rentals/duplex/3-bedrooms/non-smoking/563252. [740/741]
# Scraped 740 urls out of 741 total.
# Scraping started for https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/cumberland/pet-friendly/562576. [741/741]
# Scraped 741 urls out of 741 total.
# Scraping Finished

# %%
# @title ### Step 9: Covert data into DataFrame and saved it as a CSV (10 pts for Kijiji - 10 pts for RentFaster)

# @markdown #### **You will need to perform this twice! Once for Kijiji and Once for RentFaster, your total files will be 4 csv.**
# @markdown ---
# @markdown Now that you have your data, you will need to save it in 2 csv files, each csv file will contain the property_id along with either the overview or the details for that listing. Once you execute this cell I strongly recommend you to download the files generated by accessing them on the left side of your google colab by clicking on the folder icon.

# @markdown ---
# @markdown #### Enter a file name for unit details data (include .csv):

filename_details = "Runfasterunitdetails.csv" # @param {type:"string"}
# @markdown ---
# @markdown #### Enter a file name for property overview data (include .csv):
filename_overview = "RunfasterOverview.csv" # @param {type:"string"}
# @markdown #### Enter the website name of the data you want to save:
website = 'rentfaster' # @param ["kijiji","rentfaster"]

try:
  if website == 'kijiji':
    convert_kijiji_to_csv(all_unit_details_kk,all_property_overviews_kk,filename_details,filename_overview)
  elif website == 'rentfaster':
    convert_rentfaster_to_csv(all_unit_details,all_property_overviews,filename_details,filename_overview)
  else:
    print("Something went wrong, please check your selections")
except:
  print("Please run all steps above before executing this cell, the data should be generated before reaching this point.")

# %% [markdown]
# ## Part 2: DataFrame, Tables creation and Yelp API setup [Data Management - Total 20 pts]
#
# At this point you should have the data from Step 9 into a CSV. In this part, you are required to convert that data into spark dataframe to perfom on them your data exploration. Remember that you will be working with the raw data from our rental housing scraper, double check ALWAYS your data to better understand what you need to do with it.

# %% [markdown]
# ### Install and set up Pyspark and its associated requirements:
#
# `pyspark` is the Python API for Apache Spark, an open-source, distributed computing system that provides an interface for programming entire clusters with implicit data parallelism and fault tolerance. When dealing with web scraped data from rental listings on RentFaster and Kijiji, `pyspark` enables efficient data processing and analysis at scale. Here's how it contributes to our project:
#
# - **Data Exploration**: `pyspark` allows for comprehensive data exploration, including summarizing datasets, querying specific information (e.g., average rental prices, most common amenities), and identifying trends within the rental market of Alberta, Canada.
#
# - **Data Transformation**: The data scraped from these websites often requires cleaning and transformation to be useful for analysis. `pyspark` provides a wide array of functions for data manipulation, such as filtering, grouping, and aggregating data. This is essential for preparing the web scraped data, which may include varying formats, missing values, or irrelevant information, into a structured and analysis-ready format.
#
# `findspark` is a helper library designed to make it easier to find and start using Apache Spark's `pyspark` within Python applications. Essentially, it simplifies the process of initializing Spark in Python scripts by locating the Spark installation (which can sometimes be a challenge due to environment variables and path configurations).
#
# - **Seamless Integration**: By using `findspark`, you can more easily integrate Apache Spark into your Python environment for web scraping projects. It ensures that `pyspark` can be imported and used in your scripts as any other Python library, without the need for cumbersome setup processes or environment configuration. This is particularly useful in educational or experimental projects where simplifying the setup process can save valuable time and effort.

# %%
 # !pip install pyspark
 # !pip install findspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: findspark in /usr/local/lib/python3.10/dist-packages (2.0.1)

# %% [markdown]
# ### Spark Libraries Explained
#
# - **`os`**: This is a standard Python library that provides a way to interact with the operating system. `os` is used to perform operations like navigating the file system, changing and retrieving directory information, managing files, and accessing environment variables.
#
# - **`findspark`**: A utility library designed to make it easier to find and connect to an Apache Spark installation from Python applications. When working with Spark, setting up environment variables and paths correctly is important to successfully starting a Spark session. `findspark` simplifies this process by automatically locating the Spark installation on your system and setting the required environment variables, eliminating the need for manual configuration.
#
# - **`findspark.init()`**: This function call is used to initialize Spark in the Python script. It must be called before importing and using `pyspark`, as it sets up the environment by locating the Spark installation and setting the necessary environment variables. This step ensures that `pyspark` can be imported without issues related to finding the Spark installation.
#
# - **`pyspark`**: The Python API for Apache Spark, `pyspark` allows Python programmers to interface with Spark's distributed data processing capabilities. By importing `pyspark`, you gain access to Spark's core functionalities, including creating RDDs (Resilient Distributed Datasets), transformations, and actions on these datasets, enabling large-scale data processing.
#
# - **`from pyspark.sql import SparkSession`**: SparkSession is the entry point to programming Spark with the Dataset and DataFrame API. A SparkSession can be used to create DataFrame objects, register DataFrame as tables, execute SQL queries, and read data from an external source. Importing SparkSession is essential for working with Spark SQL and DataFrame operations, which are powerful tools for data analysis, especially when dealing with structured data like that obtained from web scraping.

# %%
import os
import findspark
findspark.init()
# only run after findspark.init()
import pyspark
from pyspark.sql import SparkSession

# %% [markdown]
# ### Step 1: Initializing a spark cluster (5 pts)
#
# Include your code below to initialize the spark cluster and add a verification step as well. Use a meaninful name for the PySpark App Name

# %%
#Your code goes here
# Create a SparkSession
spark = SparkSession.builder.appName("Web_Scraping_Project").getOrCreate()

# %% [markdown]
# Verification step

# %%
#Your code goes here
# Verify if SparkSession is created successfully
if spark:
    print("SparkSession successfully created!")
else:
    print("Failed to create SparkSession")
# Out:
# SparkSession successfully created!

# %% [markdown]
# ### Step 2: Create dataframes for analytics [Total of 15 pts]
#
# Create the PySpark dataframe with the csv data you got from Part 1 - Step 9. Remember that you can always check your files on the left folder icon within your google colab. You can use the following link to get an idea on how to do it: https://spark.apache.org/docs/latest/sql-data-sources-csv.html
#
# **Tips:**
#
# *   You should create a independent dataframe for each csv, use meaninful names!
# *   The CSV can contain newlines, to parse it you would need to consider using the "multiLine" option for `spark.read`
# *   By default headers are not including, but you need to include them! Look for the option to accomplish this
# *   Remember to use the `<your-PySparDF>.show(truncate=False)` to see how your data is looking!
# *   Check your practice Lab6 on how yo create your headers and parameters to get data from the API

# %% [markdown]
# Step 2.1: Create PySpark dataframes **Kijiji** (5 pts)

# %%
# Read the Kijiji overview data
kijiji_overview_df = spark.read.csv('kijijiOverview.csv', header=True, multiLine=True)

# Read the Kijiji details data
kijiji_details_df = spark.read.csv('kijijiunitdetails.csv', header=True, multiLine=True)

# Print the schema of the dataframes
kijiji_overview_df.printSchema()
kijiji_details_df.printSchema()

# Show the first few rows of the dataframes
kijiji_overview_df.show(truncate=False)
kijiji_details_df.show(truncate=False)
# Out:
# root
#  |-- unit_id: string (nullable = true)
#  |-- listing_url: string (nullable = true)
#  |-- date_posted: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- price_info: string (nullable = true)
#  |-- description: string (nullable = true)
#
# root
#  |-- unit_id: string (nullable = true)
#  |-- For Rent By: string (nullable = true)
#  |-- Unit Type: string (nullable = true)
#  |-- Bedrooms: string (nullable = true)
#  |-- Bathrooms: string (nullable = true)
#  |-- Agreement Type: string (nullable = true)
#  |-- Pet Friendly: string (nullable = true)
#  |-- Size (sqft): string (nullable = true)
#  |-- Furnished: string (nullable = true)
#  |-- Laundry (In Unit): string (nullable = true)
#  |-- Laundry (In Building): string (nullable = true)
#  |-- Dishwasher: string (nullable = true)
#  |-- Fridge / Freezer: string (nullable = true)
#  |-- Air Conditioning: string (nullable = true)
#  |-- Yard: string (nullable = true)
#  |-- Balcony: string (nullable = true)
#  |-- Smoking Permitted: string (nullable = true)
#  |-- Gym: string (nullable = true)
#  |-- Pool: string (nullable = true)
#  |-- Concierge: string (nullable = true)
#  |-- 24 Hour Security: string (nullable = true)
#  |-- Bicycle Parking: string (nullable = true)
#  |-- Storage Space: string (nullable = true)
#  |-- Elevator in Building: string (nullable = true)
#  |-- Wheelchair accessible: string (nullable = true)
#  |-- Braille Labels: string (nullable = true)
#  |-- Audio Prompts: string (nullable = true)
#  |-- Barrier-free Entrances and Ramps: string (nullable = true)
#  |-- Visual Aids: string (nullable = true)
#  |-- Accessible Washrooms in Suite: string (nullable = true)
#  |-- Hydro: string (nullable = true)
#  |-- Heat: string (nullable = true)
#  |-- Water: string (nullable = true)
#  |-- Cable / TV: string (nullable = true)
#  |-- Internet: string (nullable = true)
#  |-- Parking Included: string (nullable = true)
#  |-- Additional Options: string (nullable = true)
#  |-- Move-In Date: string (nullable = true)
#  |-- More Info: string (nullable = true)
#  |-- Term Agreement: string (nullable = true)
#
# +----------+-----------------------------------------------------------------------------------------------------------------------------+-------------------------+--------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |unit_id   |listing_url                                                                                                                  |date_posted              |address                                                                                                                               |price_info                                 |description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# +----------+-----------------------------------------------------------------------------------------------------------------------------+-------------------------+--------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |1687345846|https://www.kijiji.ca/v-apartments-condos/edmonton/great-bachelor-suites-downtown-call-today/1687345846                      |Posted 17 days ago       |{'address_1': '9925 Jasper Avenue NW, Edmonton, AB, T5J 2X5', 'address_2': '9925 Jasper Avenue NW, Edmonton, AB, T5J 2X5'}            |{'amt': 117500, 'cur': 'CAD', 't': 'FIXED'}|MacDonald Estates is a great property in downtown Edmonton on Jasper Avenue offering an urban lifestyleCurrent Incentives25 OFF ANY TELUS OPTIK TV AND INTERNET PRODUCTS MONTHLY12 OFF SECURITY DEPOSITS FOR MILITARY GOVERNMENT WORKERS AND FIRST RESPONDERS299 SECURITY DEPOSITS FOR THOSE 55 PLUSProperty FeaturesTransitioning to 100 smokefreeBachelor 1  2 bedroom suites downtown EdmontonLuxurious indoor poolSundeckLaundry facilities on each floorExercise facilitySecure underground parkingCentral Air ConditioningInsuite storageDishwashers not available in bachelorLarge windows with fantastic viewsClose to shopping restaurants parksClose to public transitMacDonald Estates is WELL Health  Safety CertifiedDetailed Property InformationMacDonald Estates is transitioning to become a smokefree property in downtown Edmonton The building offers residents the advantages of laundry facilities on each floor an exercise facility and secure underground parking Each spacious suite is equipped with central air conditioning extra insuite storage a dishwasher and large windows providing natural light and fantastic views Walk to numerous restaurants pubs cafs shops and the Edmonton City Center Mall is only a few blocks away As well propertyorganized events are hosted regularly that truly reflect the buildings warm community lifeLiving with Realstar  Proudly Managed by RealstarLive well with 24 hour onsite management Realstar strives to provide you with a superior living experience and exceptional resident care We organize social events that foster a sense of community Realstar buildings are impeccably clean well maintained and environmentally efficientThe rental office is open daily with 24 hour application approval Realstar makes renting easy Come view this apartment todayPrices incentives availability and specifications are subject to change Images may not reflect actual suite finishes Pet restrictions may apply E  OE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |1687403469|https://www.kijiji.ca/v-apartments-condos/edmonton/studio-in-edmonton-fmr-free-call-now/1687403469                           |Posted about 16 hours ago|{'address_1': '10054 79 Avenue NW, Edmonton, AB, T6E 1R5', 'address_2': '10054 79 Avenue NW, Edmonton, AB, T6E 1R5'}                  |{'amt': 137500, 'cur': 'CAD', 't': 'FIXED'}|The Trax is in the Strathcona community in Edmonton off Whyte Avenue and Gateway Boulevard This apartment building puts a nice twist on industrial meets modern and can easily be accessed from the downtown core Settling in and having the urban lifestyle at your fingertips is just seconds away from being yoursPROMOTION Receive your first month of rent FREE Some conditions apply please inquire for more detailsLooking for a future movein date Give us a call today to speak with one of our Customer Care Representatives to find out moreTour OptionsFaceTime  WhatsppInPersonSuite offersVinyl plank floorsLarge windows with premium roller blindsBalconies  wrap around balconies in select suitesQuartz countersSoftclose cabinetryGlass backsplashStainlesssteel appliances including microwaveand dishwasherInsuite laundryCustom Kitchen IslandsOpen concept layouts with concrete finishesWalk  through closets in select suitesProperty offersPetfriendlyFitness facilitiesUnderground Bike StorageVisitor parkingHeated underground parkingKelyless EntryVideo Surveillance and mobile securityYour community offersNear transitClose to major highwaysNear grocery stores health facilities restaurants and servicesAccess to downtown EdmontonFeesHeat and water are includedSecurity deposit  499Pet fee  25month per petParking options available check with onsite team for detailsLooking to book a tour Let our Customer Care Centre assist you Give us a call at 18449551754  Were open MondayFriday 9AM9PM EST SaturdaySunday 10AM630PM ESTTo selfbook a tour please visit our website at wwwcplivingcom and enter this property in the search barSuite images shown represent standard unit finishes which may differ between units Suite layout varies                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |1682907133|https://www.kijiji.ca/v-apartments-condos/calgary/vista-apartments-2-bedroom-2-bath-apartment-for-rent/1682907133            |Posted about 2 hours ago |{'address_1': '100 Skyview Ranch Landing NE, Calgary, AB, T3N 0V8', 'address_2': '100 Skyview Ranch Landing NE, Calgary, AB, T3N 0V8'}|{'amt': 189600, 'cur': 'CAD', 't': 'FIXED'}|Current Promotions40 off Telus Home ServicesNorthview is excited to welcome Vista Apartments to our community Vista offers 1 2 and 3 bedroom suites in North East Calgary Ask about our available specials on 2bed 2bath homesThis familyfriendly community welcomes pets and offers great amenities These homes are a convenient 5minute drive from the YYC International Airport with easy acccess to Stoney and Deerfoot TrailsEach modern home has insuite laundry a dishwasher microwave stainless steel appliances and airconditioning Suites also offer insuite storage and laminate flooring and come complete with window coveringsVista residents enjoy easy access to schools parks shopping and dining The area is connected to the citys regional pathway systemSchedule your tour todayUtilities IncludedHeatWaterProperty AmenitiesElevatorsFitness roomConvenient locationClose to ShoppingNear RestaurantsPet friendlySuite AmenitiesModern SuitesBalconiesInsuite LaundryAir ConditioningWindow Coverings IncludedStainless Steel AppliancesPromotions apply to new lease agreements Conditions may apply please contact our leasing team for detailsInformation suite availability and rental rates presented are subject to change Rental rates listed reflect starting from prices and include current incentives when applicable                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |1691117978|https://www.kijiji.ca/v-commercial-office-space/calgary/commercial-shop-for-rent-in-didsbury/1691117978                      |Posted 3 days ago        |{'address_1': 'Didsbury, AB T0M 0W0'}                                                                                                 |{'amt': 650000, 'cur': 'CAD', 't': 'FIXED'}|LOCATED IN TOWN OF DIDSBURYLong term lease available May 1 20245000 sq ft shop with offices and parts spaceOffice furniture includedMezzanine in shop with additional office and storageLots of storage area with shelvingIn floor heat in reception and kitchen area3 large 16 wide by 14 high shop doorsLarge fenced and secure yard spaceA must see to appreciate all the space availablity6500 plus utilitiesCall Joe at 403 9940279 to set up a viewing                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |1647497819|https://www.kijiji.ca/v-apartments-condos/edmonton/wellington-apartment-for-rent-wellington-park-townhomes/1647497819        |Posted 3 days ago        |{'address_1': '14001 135A Avenue NW, Edmonton, AB, T5L 2E6', 'address_2': '14001 135A Avenue NW, Edmonton, AB, T5L 2E6'}              |{'amt': 150000, 'cur': 'CAD', 't': 'FIXED'}|Wellington Park Townhomes is professionally managed by Mainstreet EquityWhen youre looking for townhomes for rent in Sherbrooke Mainstreets Wellington Park Townhomes are the perfect place to call home Petfriendly affordable nonsmoking and all in a great location This is a friendly community with bright beautiful shared green space and a lot to offer Take the heavy lifting out of moving with Mainstreet supplying your fridge stove curtains inunit washer and dryer and we even have dishwashers available Theres ample storage in the basement and youll love decorating your balcony with plants and flowers for your own private garden Homes feature a mixture of comfy carpet highgrain laminate and classic ceramic flooring and all homes come internetready and cableready Youll love the central air conditioning with individual thermostats on hot summer days so dont miss out apply online nowExclusive Pricing for TV  InternetMainstreet tenants get exclusive offers for Telus TV and InternetSome conditions apply Contact your onsite Resident Manager for more informationFlexible Rent PaymentsFlexible rent payments are provided by ZenbaseSplit your rent into two stressfree payments and budget more efficiently Contact our resident manager for additional detailsFREE Early MoveInMovein early for FREE on rentready suites after March 25th 2024 on a 12month leaseSuites must be rentready and eligible applicants must pay first months rent before movein Some units are not eligible Conditions ApplyFridgeStoveWasher in suiteIndividual thermostatsPark viewsDryer in suiteCable readyWindow coveringsInternet readyBalcony DeckFridgeStoveWindow CoveringsIn Suite StorageStorageIn Suite Laundry HookupsDishwasherLaminate floorsSecure entryVisitor parkingOnsite staffOutdoor play areaStorage roomShared yardPublic transitShopping nearbyParks nearbySchools nearbyNo Smoking allowedSecure EntryEnergized ParkingSurface ParkingPlaygroundCourtyardPatrol SecurityRental rates incentives and availability are subject to change without notice Please inquire for current availability Unit photos are provided for example only individual suite appearance may vary Rental rates are net and include current incentives on a yearly lease Please note multiple special offers cannot be combined Contact the buildings Resident Manager or Leasing Agent for more details Please note Mainstreet requires that all tenants acquire and maintain sufficient tenant insurance for the duration of their tenancy Proof of this insurance is required at time of movein Tenants may choose their insurance provider or opt for Mainstreets insurance partner                                                                                                                                                                                                                                    |
# |1689799374|https://www.kijiji.ca/v-apartments-condos/edmonton/1-bedroom-at-avalon-apartments-call-today/1689799374                      |Posted 19 days ago       |{'address_1': '9810 105th Street NW, Edmonton, AB, T5K 1A7', 'address_2': '9810 105th Street NW, Edmonton, AB, T5K 1A7'}              |{'amt': 148500, 'cur': 'CAD', 't': 'FIXED'}|Fully renovated and partially renovated 1 bedroom suites at Avalon Apartments availableCall Today25 off any Telus Optik TV and Internet product monthly199 security deposits for those 5012 off security deposits for Military Government workers and First RespondersFREE early movein when possibleRealstars Avalon Apartments is a quaint rental community in the beautiful downtown Edmonton minutes from all amenities Suites in this 14storey highrise offers residents excellent views of the River Valley and downtown We have the perfect suite for you come visit us and see for yourselfSuite FeaturesRenovated open concept bachelor 1 and 2 bedroom suitesFridge stove dishwasher  over the range microwaves in most suitesInsuite storagePrivate balconiesWindow coveringsUtilities includedProperty FeaturesElevatorUnderground parking24 hour onsite managementSmokefreePetfreeLocationAvalon Apartments is located in desirable downtown Edmonton just blocks from the Legislative grounds Jasper Avenue and the River Valley It is very close to shopping and bus routes with our excellent location and ease of getting around the city Dont miss your opportunity to secure a home today at Avalon ApartmentsLive well at Avalon Apartments  Proudly Managed by RealstarLive well with 24hour onsite management Realstar strives to provide you with a superior living experience and exceptional resident care We organize social events that foster a sense of community Realstar buildings are impeccably clean well maintained and environmentally efficientThe rental office is open daily with 24hour application approval Realstar makes renting easy Come view this apartment todayPrices incentives availability and specifications are subject to change Images may not reflect actual suite finishes E  O E                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |1691051473|https://www.kijiji.ca/v-commercial-office-space/edmonton/athabasca-ab-commercial-retail-space-for-lease/1691051473           |Posted 4 days ago        |{'address_1': 'Athabasca, AB T9S 1A7'}                                                                                                |{'cur': 'CAD', 't': 'CONTACT'}             |Available now Commercial retail space in Athabasca AB for Lease Ideal for a small business shop A perfect setup for a new business ownerPlease call 7809844158 Paul                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |1691051151|https://www.kijiji.ca/v-commercial-office-space/edmonton/commercial-building-restaurant-bar-liquor-store-for-lease/1691051151|Posted 4 days ago        |{'address_1': 'Lac la Biche, AB T0A 2C0'}                                                                                             |{'cur': 'CAD', 't': 'CONTACT'}             |Available Now Commercial Building will develop business already in place for Lease located in the heart of Lac La Biche townPlease contact 7809844158 Pau                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |1691050752|https://www.kijiji.ca/v-apartments-condos/lloydminster-ab/3-bedroom-sask-duplex/1691050752                                   |Posted 4 days ago        |{'address_1': '47 Ave, Lloydminster, SK S9V 1H3', 'address_2': '47 Ave, Lloydminster, SK S9V 1H3'}                                    |{'amt': 130000, 'cur': 'CAD', 't': 'FIXED'}|Available June 1Fully fenced and landscaped back yard with a shedClose to elementary schools and playgroundsAppliances include washer dryer fridge  stoveApplications with rental references are required1300month plus utilities1300 DD3068212577Email bendick5telusnet for an application                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |1691050513|https://www.kijiji.ca/v-apartments-condos/edmonton/luxury-full-townhouse-4-beds-developed-bsmt-single-garage/1691050513      |Posted 4 days ago        |{'address_1': '16218 97 Avenue Northwest, Edmonton, AB', 'address_2': '16218 97 Avenue Northwest, Edmonton, AB'}                      |{'amt': 239500, 'cur': 'CAD', 't': 'FIXED'}|LUXURY FULL TOWNHOUSE  4 BED35 BATHDEVELOPED BSMT  SINGLE GARAGE  TANDEM PARKINGMove IN TodayAddress 16218 97 Ave Edmonton AB T5P 1L5 Rent 2395  Utilities Single Car Garage  Tandem Parking Included  Sorry No Pets Allowed Credit Reference  Employment Check will be required with applicationsInquire Now Email infopropfitcaOr CALLTEXT 780 9643022 to view it todayFEATURES1 4 BEDROOMS 35 BATHROOM 2 PARKING  1 SINGLE GARAGE2 Luxury Full Townhouse with DEVELOPED BASEMENT with family room3 TONS of LUXURIOUS UPGRADES including STAINLESS STEEL Appliances QUARTZ Countertop  a Corner Pantry for extra groceries4 BONUS A small Landscaped FENCED BackyardPrime Location in Glenwood community Close to Transit Schools West Edmonton Mall and MoreYES You read it rightThis middle unit townhouse with TONS OF UPGRADES is waiting for a great family to make it a HOMELets head to the main entrance You will be invited by this spacious living room for you and your family to hang out It has a LARGE window that provides plenty of natural sunlight from dawn till duskThe dining area is situated beside your living room where everyone can enjoy their meals The kitchen is situated right at the corner This kitchen gives you STAINLESS STEEL Appliances QUARTZ Countertop LOTS of Cabinet spaces  a Corner Pantry for extra groceries This is a kitchen that everyone is yearning forPLUS Basement is DEVELOPED YES You do have an extra bedroom living area  full bath that you can call a man cave guest suite or playroom for your children How awesomeThis home has a small landscaped FENCED backyard What a perfect way to enjoy BBQ  family gettogether outdoorPrime Location in Glenwood has easy access to major bus routes and popular schools in Edmonton Close to major attractions including West Edmonton Mall and River Cree Resort Great community that has kids park walking trails and pathwaysEdmonton Public SchoolsGlendale Elementary SchoolWestlawn Junior High SchoolEdmonton Catholic SchoolsSt Thomas More Junior High SchoolIndependently Operated SchoolsMeadowlark Christian SchoolInquire Now Email infopropfitcaOr CALLTEXT 780 9643022 to view it todayOffered by PropFit Inc A professional property management group licensed under Professional Realty GroupAdvertised price reflects after discount rate for a tenant paying on or before the 1st of the month and following lease rules and regulations                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |1691050048|https://www.kijiji.ca/v-apartments-condos/edmonton/95-ready-brand-new-tons-of-natural-light-stunning-modern-suite/1691050048 |Posted 4 days ago        |{'address_1': '15912 96 Street, Edmonton, AB', 'address_2': '15912 96 Street, Edmonton, AB'}                                          |{'amt': 119800, 'cur': 'CAD', 't': 'FIXED'}|95 Ready Brand NewTons of Natural LightStunningModernHigh CeilingLegal BSMT SuiteLEGAL BASEMENT SUITE 15912  96 AVENUE NW Edmonton 1 Bedroom  1 Bathroom  Private entrance and In Suite Laundry RENT 1198  200 Flat Rate Utilities Power Water Heat  Waste Maximum occupancy 2 people 1 small pet negotiable extra 50pet monthly pet fee applies Credit Reference  employment check will be required with applications Street parking only Available May 1st2024Inquire NowOr CALLTEXT 7809643022 to view it today FEATURES1 BEAUTIFUL BRAND NEW 1 Bedroom 1 Bath Legal Basement Unit2 Separate Entrance 100 private access no sharing with Mainfloor Tenant3 Separate Heating Control your temperature never too hot or too cold4 Separate INSUITE Washer  Dryer Leave your clothes in the dryer overnight no problem5 Open Concept with BRIGHT SPACIOUS LIVING ROOM with HUGE WINDOWS You deserve way more than a Dark Cold Moldy Basement6  Stunning Modern Kitchen with STAINLESS STEEL APPLIANCES INCLUDING DISHWASHER  MICROWAVE7 Huge Bedroom with Luxury Vinyl Plank Flooring throwout No Carpet easy to clean8 Prime Location in Glenwood community Close to Transit Schools West Edmonton Mall and MoreInquire NowOr CALLTEXT 7809643022 to view it today Offered by Professional Realty GroupAdvertised price reflects after discount rate for a tenant paying on or before the1st of the month and following lease rules and regulations                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# ...
# only showing top 20 rows
#
# +----------+------------+--------------+---------------+---------+--------------+------------+-----------+---------+-----------------+---------------------+----------+----------------+----------------+----+-------+-----------------+----+----+---------+----------------+---------------+-------------+--------------------+---------------------+--------------+-------------+--------------------------------+-----------+-----------------------------+-----+----+-----+----------+--------+----------------+------------------+------------+---------+--------------+
# |unit_id   |For Rent By |Unit Type     |Bedrooms       |Bathrooms|Agreement Type|Pet Friendly|Size (sqft)|Furnished|Laundry (In Unit)|Laundry (In Building)|Dishwasher|Fridge / Freezer|Air Conditioning|Yard|Balcony|Smoking Permitted|Gym |Pool|Concierge|24 Hour Security|Bicycle Parking|Storage Space|Elevator in Building|Wheelchair accessible|Braille Labels|Audio Prompts|Barrier-free Entrances and Ramps|Visual Aids|Accessible Washrooms in Suite|Hydro|Heat|Water|Cable / TV|Internet|Parking Included|Additional Options|Move-In Date|More Info|Term Agreement|
# +----------+------------+--------------+---------------+---------+--------------+------------+-----------+---------+-----------------+---------------------+----------+----------------+----------------+----+-------+-----------------+----+----+---------+----------------+---------------+-------------+--------------------+---------------------+--------------+-------------+--------------------------------+-----------+-----------------------------+-----+----+-----+----------+--------+----------------+------------------+------------+---------+--------------+
# |1687345846|Professional|Apartment     |Bachelor/Studio|1        |1 Year        |Yes         |NULL       |No       |No               |Yes                  |Yes       |Yes             |Yes             |No  |No     |No               |Yes |Yes |No       |No              |No             |No           |Yes                 |No                   |No            |No           |No                              |No         |No                           |Yes  |Yes |Yes  |No        |No      |0               |NULL              |NULL        |NULL     |NULL          |
# |1687403469|Professional|Apartment     |Bachelor/Studio|1        |1 Year        |Limited     |NULL       |No       |Yes              |No                   |Yes       |Yes             |No              |No  |Yes    |No               |Yes |No  |No       |No              |No             |No           |No                  |No                   |No            |No           |No                              |No         |No                           |No   |Yes |Yes  |No        |No      |0               |NULL              |NULL        |NULL     |NULL          |
# |1682907133|Professional|Apartment     |2              |2        |1 Year        |Yes         |NULL       |No       |No               |No                   |No        |No              |No              |No  |No     |No               |No  |No  |No       |No              |No             |No           |Yes                 |No                   |No            |No           |No                              |No         |No                           |No   |Yes |Yes  |No        |No      |0               |NULL              |NULL        |NULL     |NULL          |
# |1691117978|Owner       |NULL          |NULL           |NULL     |NULL          |NULL        |NULL       |Yes      |NULL             |NULL                 |NULL      |NULL            |NULL            |NULL|NULL   |NULL             |NULL|NULL|NULL     |NULL            |NULL           |NULL         |NULL                |NULL                 |NULL          |NULL         |NULL                            |NULL       |NULL                         |NULL |NULL|NULL |NULL      |NULL    |NULL            |NULL              |NULL        |NULL     |NULL          |
# |1647497819|Professional|House         |3              |1        |1 Year        |Limited     |NULL       |No       |Yes              |No                   |No        |Yes             |No              |Yes |No     |No               |No  |No  |No       |No              |No             |No           |No                  |No                   |No            |No           |No                              |No         |No                           |No   |No  |No   |No        |No      |0               |NULL              |NULL        |NULL     |NULL          |
# |1689799374|Professional|Apartment     |1              |1        |1 Year        |No          |NULL       |No       |No               |Yes                  |Yes       |Yes             |No              |No  |Yes    |No               |No  |No  |No       |No              |No             |No           |Yes                 |No                   |No            |No           |No                              |No         |No                           |Yes  |Yes |Yes  |No        |No      |0               |NULL              |NULL        |NULL     |NULL          |
# |1691051473|Owner       |NULL          |NULL           |NULL     |NULL          |NULL        |NULL       |No       |NULL             |NULL                 |NULL      |NULL            |NULL            |NULL|NULL   |NULL             |NULL|NULL|NULL     |NULL            |NULL           |NULL         |NULL                |NULL                 |NULL          |NULL         |NULL                            |NULL       |NULL                         |NULL |NULL|NULL |NULL      |NULL    |NULL            |NULL              |NULL        |NULL     |NULL          |
# |1691051151|Owner       |NULL          |NULL           |NULL     |NULL          |NULL        |NULL       |Yes      |NULL             |NULL                 |NULL      |NULL            |NULL            |NULL|NULL   |NULL             |NULL|NULL|NULL     |NULL            |NULL           |NULL         |NULL                |NULL                 |NULL          |NULL         |NULL                            |NULL       |NULL                         |NULL |NULL|NULL |NULL      |NULL    |NULL            |NULL              |NULL        |NULL     |NULL          |
# |1691050752|Owner       |Duplex/Triplex|3              |1.5      |1 Year        |Limited     |NULL       |No       |No               |No                   |No        |No              |No              |No  |No     |No               |No  |No  |No       |No              |No             |No           |No                  |No                   |No            |No           |No                              |No         |No                           |No   |No  |No   |No        |No      |2               |NULL              |NULL        |NULL     |NULL          |
# |1691050513|Owner       |Townhouse     |4              |3.5      |1 Year        |No          |NULL       |No       |Yes              |No                   |Yes       |Yes             |No              |Yes |No     |No               |No  |No  |No       |No              |No             |No           |No                  |No                   |No            |No           |No                              |No         |No                           |No   |No  |No   |No        |No      |2               |NULL              |NULL        |NULL     |NULL          |
# |1691050048|Owner       |Basement      |1              |1        |1 Year        |Yes         |NULL       |No       |Yes              |No                   |Yes       |Yes             |No              |No  |No     |No               |No  |No  |No       |No              |No             |No           |No                  |No                   |No            |No           |No                              |No         |No                           |No   |No  |No   |No        |No      |0               |NULL              |NULL        |NULL     |NULL          |
# |1691049783|Owner       |NULL          |NULL           |NULL     |NULL          |NULL        |NULL       |No       |NULL             |NULL                 |NULL      |NULL            |NULL            |NULL|NULL   |NULL             |NULL|NULL|NULL     |NULL            |NULL           |NULL         |NULL                |NULL                 |NULL          |NULL         |NULL                            |NULL       |NULL                         |NULL |NULL|NULL |NULL      |NULL    |NULL            |NULL              |NULL        |NULL     |NULL          |
# |1691046332|Professional|Apartment     |1              |1        |1 Year        |Limited     |NULL       |No       |No               |Yes                  |Yes       |Yes             |No              |No  |Yes    |No               |Yes |Yes |No       |Yes             |No             |No           |Yes                 |No                   |No            |No           |No                              |No         |No                           |No   |Yes |Yes  |No        |No      |0               |NULL              |NULL        |NULL     |NULL          |
# |1691048400|Owner       |Condo         |1 + Den        |2        |1 Year        |No          |NULL       |Yes      |Yes              |No                   |Yes       |Yes             |Yes             |No  |Yes    |Outdoors only    |No  |No  |No       |No              |No             |No           |Yes                 |No                   |No            |No           |No                              |No         |No                           |No   |Yes |Yes  |No        |No      |1               |NULL              |NULL        |NULL     |NULL          |
# |1691047988|Owner       |Basement      |1 + Den        |1        |1 Year        |No          |NULL       |No       |No               |No                   |No        |No              |Yes             |No  |No     |No               |No  |No  |No       |No              |No             |No           |No                  |No                   |No            |No           |No                              |No         |No                           |No   |No  |No   |No        |No      |1               |NULL              |NULL        |NULL     |NULL          |
# |1687190354|Owner       |NULL          |NULL           |NULL     |NULL          |NULL        |NULL       |No       |NULL             |NULL                 |NULL      |NULL            |NULL            |NULL|NULL   |NULL             |NULL|NULL|NULL     |NULL            |NULL           |NULL         |NULL                |NULL                 |NULL          |NULL         |NULL                            |NULL       |NULL                         |NULL |NULL|NULL |NULL      |NULL    |NULL            |NULL              |NULL        |NULL     |NULL          |
# |1691046784|Professional|Townhouse     |3              |1.5      |1 Year        |Yes         |NULL       |No       |Yes              |No                   |Yes       |Yes             |No              |Yes |Yes    |No               |No  |No  |No       |No              |No             |No           |No                  |No                   |No            |No           |No                              |No         |No                           |No   |No  |Yes  |No        |No      |2               |NULL              |NULL        |NULL     |NULL          |
# |1691046447|Professional|NULL          |2              |2        |NULL          |No          |NULL       |Yes      |NULL             |NULL                 |NULL      |NULL            |NULL            |NULL|NULL   |NULL             |NULL|NULL|NULL     |NULL            |NULL           |NULL         |NULL                |NULL                 |NULL          |NULL         |NULL                            |NULL       |NULL                         |NULL |NULL|NULL |NULL      |NULL    |NULL            |NULL              |NULL        |NULL     |NULL          |
# |1691046758|Professional|Townhouse     |3              |1.5      |1 Year        |No          |NULL       |No       |Yes              |No                   |Yes       |Yes             |No              |Yes |No     |No               |No  |No  |No       |No              |No             |No           |No                  |No                   |No            |No           |No                              |No         |No                           |No   |No  |Yes  |No        |No      |1               |NULL              |NULL        |NULL     |NULL          |
# |1691046754|Professional|House         |2 + Den        |1        |1 Year        |No          |NULL       |No       |Yes              |No                   |Yes       |Yes             |No              |No  |No     |No               |No  |No  |No       |No              |No             |No           |No                  |No                   |No            |No           |No                              |No         |No                           |No   |No  |No   |No        |No      |1               |NULL              |NULL        |NULL     |NULL          |
# +----------+------------+--------------+---------------+---------+--------------+------------+-----------+---------+-----------------+---------------------+----------+----------------+----------------+----+-------+-----------------+----+----+---------+----------------+---------------+-------------+--------------------+---------------------+--------------+-------------+--------------------------------+-----------+-----------------------------+-----+----+-----+----------+--------+----------------+------------------+------------+---------+--------------+
# only showing top 20 rows

# %%
#Your code goes here

# %% [markdown]
# Step 2.2: Create PySpark dataframes **RentFaster** (5 pts)

# %%
# Read the RentFaster overview data
rentfaster_overview_df = spark.read.csv('RunfasterOverview.csv', header=True, multiLine=True)

# Read the RentFaster details data
rentfaster_details_df = spark.read.csv('Runfasterunitdetails.csv', header=True, multiLine=True)

# Print the schema of the dataframes
rentfaster_overview_df.printSchema()
rentfaster_details_df.printSchema()

# Show the first few rows of the dataframes
rentfaster_overview_df.show(truncate=False)
rentfaster_details_df.show(truncate=False)
# Out:
# root
#  |-- property_id: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- slogan: string (nullable = true)
#  |-- priceRange: string (nullable = true)
#  |-- telephone: string (nullable = true)
#  |-- image: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- amenities: string (nullable = true)
#
# root
#  |-- unit_id: string (nullable = true)
#  |-- property_id: string (nullable = true)
#  |-- unit_name: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- squareFeet: string (nullable = true)
#  |-- availabilityDate: string (nullable = true)
#  |-- utilitiesIncluded: string (nullable = true)
#
# +-----------+------+-----------------+-------------------------------+-----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+--------------+----------+---------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |property_id|id    |location         |name                           |url                                                                                                  |slogan                                                                                                                  |priceRange    |telephone |image                                                                                                                                  |description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# +-----------+------+-----------------+-------------------------------+-----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+--------------+----------+---------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |554875     |554875|/ab/edmonton     |The Willow                     |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/queen-mary-park/pet-friendly/554875|Get 1-month FREE rent plus choose between 3 months FREE parking or 3 months FREE utilities, and receive a $300 prepaid g|$1,540 - 1,555|5874140077|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/554875/9858713.v.2cad9fae4e26dbe9c29fd24f98597c93.jpg|Discover The Willow  NEW luxury petfriendly apartment rentals centrally located in Queen Mary Park EdmontonTake advantage of our April offer One month rentfree on a 13month lease Plus choose between three months of complimentary parking or utilitiesAct now as our units are filling up fast  were already 90 leasedEmbrace a refined lifestyle amidst urban parks and conveniences Select from our array of suites including onebedroom twobedroom twobedroom plus den layouts and threebedroom townhomes Each unit is meticulously crafted for modern living with premium finishes like luxury vinyl plank flooring 9foot ceilings contemporary lighting air conditioning insuite laundry energysaving green features and a private terrace or balcony At The Willow an abundance of amenities awaits from a social room and fitness center to a sprawling rooftop terrace bike room and pet washWe also welcome dogs of all breeds and sizesBeing minutes from both downtown Edmonton and the river valley helps you balance city life while still getting away from it all We are situated minutes from MacEwan University NAIT Royal Alexandra Hospital and 124thStreetfor all your essential needsDont miss out on securing your new home at The Willow  contact our leasing team today at 5879903812Current IncentivesA choice of 3 months free utilities OR 3 months free parkingWelcome basket including 300 prepaid VISAMove in up to a week early at no chargeAdditionalVideo surveillanceIndividual thermostatsWalkin closetsCable readySchools nearbyInternet readyRooftop BBQ AreaPetBike wash                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# |540024     |540024|/ab/edmonton     |The Legacy at Griesbach        |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/griesbach/pet-friendly/540024      |The Legacy at Griesbach                                                                                                 |$1,695        |5874001246|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/540024/9440063.v.f64d94f3d6e1f1587d230881bc25dffc.jpg|AdditionalEnsuite bathroomWalkin closetsSchools nearbyWalking trailsITBusiness centre Basketball courtCommunity barbequesElectric vehicle charging stations247 customer careQuartz countertopsEvent space with kitchenStainless steel appliancesPackage locker roomNew propertyPetfriendly pet restrictions applyHighgloss cabinetsSoftclose cabinetry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# |549526     |549526|/ab/edmonton     |University 114                 |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/mckernan/pet-friendly/549526       |Modern comforts, timeless style!                                                                                        |$1,282 - 2,194|5877139762|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/549526/9746409.v.d27157ae4ea7fb6820d0958aacb1cb15.jpg|Welcome to University OneFourteen where modern comforts and timeless style seamlessly merge Designed by the esteemed ONYMOUS Architecture our community embodies a vibrant energy and a strong sense of belonging Opening in Fall 2023Indulge in the convenience of our extensive onsite amenities Immerse yourself in the beauty of our meticulously landscaped surroundings and captivating courtyard Connect and socialize with your neighbors in our inviting main floor amenity room and meeting space Effortlessly access your floor with our convenient elevators and enjoy the added security and convenience of underground parkingChoose from our meticulously designed studio one and twobedroom suites each thoughtfully crafted to create a space you can truly call home Whether youre a student embarking on an academic journey or a young professional chasing your career dreams our apartments cater to your unique needs and aspirations Experience modern finishes complemented by thoughtful touches that provide a haven of comfort and relaxationPicassohttpsyoutubeWckLfj8T6TIKinghttpsyoutubeZKTZlphqcoAdditionalVideo surveillanceEnsuite bathroom247 emergency serviceCity Recreation Center Vinyl FloorsInsuite safePet WashMain Floor RetailersParcel LockersRestaurants nearbyCommunity Centre                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# |561691     |561691|/ab/sherwood-park|Park Centre Place              |https://www.rentfaster.ca/ab/sherwood-park/rentals/apartment/2-bedrooms/pet-friendly/561691          |Park Centre Place                                                                                                       |$1,950 - 2,493|5875708501|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/561691/9804684.v.aa535a20ac6f8181260f5ecf06115950.jpg|1 Month Free on a 13month LeasePark Centre Place is in the heart of Sherwood Park it has a variety of brand new luxurious finishes and 11 different floor plans It is a brandnew petfriendly building featuring spacious airconditioned suites and it is in a safe and vibrant community Park Centre Place issteps away from local transportation grocery stores restaurants schools fitness centers and parksWith amenities like beautifully landscaped courtyards and an onsite 24hour Fitness center theres something here for everyone looking to establish healthier routines or just relax in style with stunning views from the rooftop loungeKitchens are designed for the modern lifestyle featuring sleek quartz countertops and backsplash plus softclose cabinetry With stainless steel appliances wide plank wood flooring throughout your home adds warmth to your living space while illuminated bathroom mirrors bring a touch of luxe design into the mix Your apartment offers an insuite washer and dryer dishwasher and smart locks for keyless entry to the building We provide an accessible building by using resources such as elevators where you can access your rooftop lounge and rampsWe strive to provide a culture that will encourage a positive and safe environment where you can explore the neighborhood on your bike or foot We offer secure bike storage units and facilities tokeep your twowheeled adventure rolling With our customdesigned lockers bike wash stations amp repair centers as well as ebike charging options  youll be ready for an amazing journey at the start of every dayVIRTUAL TOURSJade I B1Amber I ABuilding FeaturesStudios 1 2 3 bedroom floorplansFOB key system for common areas and suitesOnsite 5star management serviceFully equipped 24hour gymKitchen and amenity loungeOutdoor roof top amenity areaPet friendlyBike storageCats and small dogs permitted upon approval fees apply Applicable to select unitsProfessionally Managed By Zen Residential LtdRates deposits and incentives are based on applicable lease terms on approved credit and are subject to change without notice some conditions apply Photographs are for advertising purposes only and may not be of the actual suite availableAdditionalVideo surveillanceConvenience storeWalkin closetsSecurity onsiteSchools nearbyComplimentary WiFi in Garage Rooftop BBQ AreaQuartz CountertopsTall CabinetsRooftop Patio With BBQStone countertopsPrivate bycicle storageScenic viewContemporary Kitchens with Additional storageChrome faucets amp hardwareBreakfast bars on select unitsKitchen island on select unitsTile backsplashMoen bathroom fixtures in all unitsUndermount sinkFull width mirror above vanitySoft closing cabinets amp drawersEnergy efficient Insuite washer amp dryer2 levels of underground parkingQuartz countertops tiled backsplashEasy access to Anthony HendayNear grocery Walmart and SuperstoreBus routes close byOutdoor LoungeModern high gloss laminate cabinetryQuartz countertops with stainless steel undermount double bowl sink  30 stainless steel refrigerator and bottom freezer drawer  30 4burner electric range  24 stainless steel dishwasher  30 over the range microwaveYoga roomEasy access to the YellowheadSecurity CameraBBQ StationsResident Social EventsSnaile Locker Storage                                                                                                                                                                                                                                                                                                      ...
# |478927     |478927|/ab/edmonton     |Jasper Heights Apartments      |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/478927       |Jasper Heights Apartments                                                                                               |$1,167 - 2,009|5878050277|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/478927/8776630.v.96736970f1bba359e4cb48732f6d03cf.jpg|Welcome to Jasper Heights The high end finishes complement the spacious floor layouts in this 19 storey tower offering spectacular city views Jasper Heights is a pet friendly community and ideal for professionals students and seniors looking for convenience affordability and lifestyleEnjoy time in the incredible amenity space from the onsite gym to relaxingin the expansive resident loungeSuite FeaturesStudio and 1 bedroom suitesStunning viewsStainless steel appliancesVinyl plank flooringGranite countertopsInsuite air conditioningLarge closetsInsuite storagePet friendly upon approval fees applySocial SpaceFitness RoomAccess to Bay Enterprise Square station and bus routes just outside your doorEDMONTON POLICE SERVICE CRIME FREE MULTIHOUSING PROGRAM IN EFFECTINCENTIVE Whether youre a new or existing TELUS customer as residents of Unitii you are eligible for 25 Discount on TELUS Optik TV amp Internet Ask your building manager for more detailsunitii is proud to announce our new partnership with The Brick All unitii residents qualify for an exclusive discount on furniture Contact your building manager for more detailsIf you are looking to soak in the downtown lifestyle  look no furtherAdditionalVideo surveillance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# |433936     |433936|/ab/edmonton     |Jasper One Eleven              |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/433936       |Jasper One Eleven                                                                                                       |$1,434 - 2,725|5874161277|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/433936/8793038.v.55f171e8a090ce09fbb3164b4a91e9f3.jpg|Contact us to learn more about our beautiful spacious and newly renovated penthouse units Special promotion for spring move ins amp much moreReceive 1 month free on select unitsSome conditions apply Speak to a leasing agent for detailsWELCOME TOJasper One ElevenJasper One Eleven is located in the heart of downtown Edmonton This community offers comfort and convenience at your doorstep  with an array of shops restaurants andcozy cafs Within easy walking distance to Grant MacEwan College provincial government buildings beautiful parks and the scenic River Valley there is so much to exploreGWL Realty Advisors Residential is dedicated to providing residents with swift responsive service Our buildings are impeccably clean and environmentally efficient The company creates a sense of community within each property while also connecting with the surrounding community through socialresponsibility programs We are consistently raising standards to elevate rental living to new heights of service quality and innovationPlease note that all rents listed are starting prices only Prices subject to change without noticeAdditionalSpacious Suite Layout                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# |517036     |517036|/ab/edmonton     |Citizen on Jasper              |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/517036         |Luxury Living on Jasper Ave.                                                                                            |$1,733 - 3,386|5875708745|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/517036/9259435.v.69730050fc0ab5b057ccd86a1818609d.jpg|Located on Jasper Avenue and 120 Street NW Citizen is at the heart of Jasper Avenues independent food beverage and retail scene Walk downtown and to 124 Grand Markets fresh produce stalls and food trucksBuilding AmenitiesGrand LobbySky LoungeOutdoor Hot Tub and TerracesMultiSport SimulatorMedia LoungeState of The Art Gym and Fitness StudioGuest SuiteHeated Underground ParkingBike StorageSmart Parcel LockersLevel 2 Outdoor Dog ParkConcierge and SecurityDemonstration KitchenExclusive Resident EventsResident Experience ServicesConceirge amp Community Manager247 EmergencyMaintenanceInSuite Maintenance ServicesResidents EventsBuilding GreenCitizen has been carefully planned designed and constructed to minimize environmental impact and optimize the health of our residents Natural LightingWaterConscious Features Connectivity and Clean AirSuite FeaturesELEVATED INTERIORSChoice of three contemporary palettes Morning Noon and DuskSoaring 9 ceilings in main living areas 10 ceilings on select suites and 11 penthouse ceilingsGenerous natural light and breathtaking viewsEnergyefficient privacygrade roller shade window coveringsContemporary woodgrain plank flooring throughoutSolid core interior doors for improved acousticsSuites are prewired with highspeed fibre optic wiring to provide Telus fibre and Shaw coax installationsIndividual unitcontrolled heating and coolingIndividual energyefficient fancoil units with advanced air filtrationInsuite laundryfront loadingLarge open balconies with each unitDESIGNER KITCHENSPremium Whirlpool stainless steel appliancesSmart contemporary range with touchscreenMicrowave with multistep cookingFull capacity dishwasherSleek refrigeratorNatural stone quartz countertopsUndermount stainless steel sinksChrome Kohler pulldown faucetContemporary fullheight cabinetsSelect units include an island with extra storage and eating bar optionsELEGANT BATHROOMSQuartz countertops with integrated sinksShower and soaker tub combinationBuiltin medicine cabinet mirrorsEnergyefficient lighting throughoutPorcelain tile on all wet wall surroundsAdditionalVideo surveillanceEnsuite bathroomIndividual thermostatsWalkin closetsCable readySecurity onsiteInternet readyGarbage ChuteRoller shade window coveringsSleek and modern cabinetsDog Wash StationOutdoor Patio LoungeOutdoor Patio LoungeFurnished Guest SuiteQuartz CountertopsPorcelain tile backsplashIndoor parcel pending lockersBicycle wash station and bicycle repairmaintenance roomDemonstration kitchen and dining areaEdmonton River ValleyUniversity of AlbertaCommunal BBQDemonstration KitchenPrivate Meeting  Dining RoomConcierge and SecurityResident Events and Fitness ClassesIndoor LoungeWifi In Common AreasWiFi in Common AreasGames AreaMedia RoomFully Equipped Guest SuitesYoga StudioLuxer Parcel LockersOn Site Security  247CoWorking SpaceElectronic ThermostatMedia LoungeEfficient AppliancesExclusive Resident PerksDemonstration Kitchen amp Dining RoomStainless Steel Smart AppliancesOutdoor Lounge PatioBike Storage amp Bike Wash StationDog SpaStylish Chrome Hardware and FixturesDesigner Lighting PackageTall CeilingsHighSpeed Fibre Optic Wiring24Hour SecurityBilliardsResident EventsHospitality SuitesComplimentary WIFI in social areas247 emergency serviceCoffee bar with seating areaHigh CeilingsLobby Fireplace with seating areaSecured parcel lockers and roomPet SpaElectronic SMART ThermostatChange rooms with showerMulti Sport Simulator lounge roomRoller shades in every suite typeGames Lounge Pool tablePrivate balconies included in every sui ...
# |437717     |437717|/ab/edmonton     |The Hendrix                    |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/oliver/pet-friendly/437717         |The Hendrix                                                                                                             |$1,479 - 2,919|5874029250|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/437717/8668473.v.61f3ecbcdc0f9954eb17f003d058914d.jpg|WELCOME TOThe HendrixA new level of living awaits your arrival at The Hendrix Nestled In the sought after Oliver neighbourhood every convenience has been carefully considered and every detail has been thoughtfully addressed to provide you with the ultimate in comfort and style At The Hendrix our residents are offered some of the best amenities available anywhere in the cityGWL Realty Advisors Residential is dedicated to providing residents with swift responsive service Our buildings are impeccably clean and environmentally efficient The company creates a sense of community within each property while also connecting with the surrounding community through socialresponsibility programs We are consistently raising standards to elevate rental living to new heights of service quality and innovationPlease note that all rents listed are starting prices only Prices subject to change without noticeAdditionalRooftop BBQ AreaDog RunOpen Concept DesignCoffee RoomPackage Receiving                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# ...
# |255055     |255055|/ab/edmonton     |Richard House /Kerry Manor     |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/downtown/pet-friendly/255055       |Look no further for your new home!                                                                                      |$1,049        |5874003743|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/255055/4144138.v.46b8c81bb97ea694bb3c05af171fc374.jpg|Receive a 500 gift card upon moving in if your application is received within 48 hours of the showingResidents of Richard House amp Kerry ManorCan Receive 40 off Telus Home Services or Exclusive Deals with Shaw See site manager for details subject to TelusShaw availability amp conditionsFor a more immersive experience try our virtual tours1 Bedroom 360 Tour or 2Bedroom 360 TourThese buildings are located just two blocks south of Unity Squareincluding the new Brewery District and only two blocks north of trendy Jasper Avenue That makes it walking distance to transit services shopping and fantastic new restaurants and clubsRichard House and Kerry Manor both feature bachelor one or twobedroom rental options with balconies some suites and window coverings on a beautiful treelined street Heat water amp one parking stall includedCats only permitted upon approval fees apply Security Deposit only 699Outdoor parking is available1 stall  10mth2 stalls  35mth 10 for 1st 25 for 2ndProfessionally Managed By Zen Residential LtdRates deposits and incentives are based on applicable lease terms on approved credit and are subject to change without notice some conditions apply Photographs are for advertising purposes only and may not be of the actual suite availableBOOK AN APPOINTMENT TODAY1 Bedroom 360 Tour or 2Bedroom 360 TourOliveris one of the oldest residential neighbourhoods in the City ofEdmontonAlbertaCanada The neighbourhood is named afterFrank Oliver an early Edmonton resident businessman and politician The south east portion of the neighbourhood is also known asGrandin with both Grandin station now known asGovernment Centre stationand Grandin School located in this part of the neighbourhoodResidential towers along 100 Avenue in OliverOliver is located immediately to the west of thedowntown core and overlooks theNorth Saskatchewan Rivervalley south of the neighbourhood Located in the river valley immediately below Oliver is EdmontonsRoyal Glenora Club Victoria Golf Course andVictoria Park TheHigh Level BridgeandGroat Bridgegive residents access to the south side of the river valley including theUniversity of AlbertaandOld Strathcona The Victoria Promenade part of Edmontons Heritage Trail offers attractive vistas of the river valley at the western end of OliverOliver is one of the densest neighbourhoods in Edmonton and West Oliver is the densest area in Alberta The population in 2009 was 18203 the highest of every neighbourhood in Edmonton7The north edge of the neighbourhood was once aCanadian National Railwayright of way and rail yard This part of the neighbourhood was recently redeveloped and includes apartment buildings the Unity Square and Unity Square West strip shopping centres some old warehouses converted shops and parking for theMacEwan Universitydowntown campusThe community is represented by the OliverCommunity League established in 192289AdditionalConvenience storeIndividual thermostatsCable readySchools nearbyInternet ready                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# |455313     |455313|/ab/edmonton     |4-8 Hooper Crescent            |https://www.rentfaster.ca/ab/edmonton/rentals/apartment/1-bedroom/overlanders/pet-friendly/455313    |VICTORIA COUNTY                                                                                                         |$1,175 - 1,635|8256015562|https://f1a3d4fea3a9a877e732-356deb4d9644d2835b7712e712dbd1ea.ssl.cf2.rackcdn.com/455313/8535510.v.77696bbd321a7ba2ae6815017edc0c52.jpg|Welcome to Victoria County in EdmontonFind peace and security with Victoria County and enjoy weekends exploring all that Edmonton has to offer you Settle in to a safe and comfortable community today Conveniently located in a selfcontained community close to Edmontons parks and walking trails schools shopping restaurants and other amenities adventure and urban life awaits you at Victoria CountyWhen you rent with Avenue Living Communities youre choosing the advantage EnjoyPet friendly communities24hour resident serviceThreeday maintenance turnaroundProfessional cleaning amp landscapingOnsite management teamReferafriend programAND even more benefits that make renting with us simpleSpecial OffersRent payment reporting to Equifax and flexible rent payments available  Powered by ZenbaseExclusive TELUS Offer Save 25on any Internet tier and Optik TV products as an ALC resident in AlbertaPlus enjoy fast fibre optic internet speeds in this propertySuite amp BuildingOne two and threebedroom suitesSpacious and bright living rooms with large windowsSuites come with appliances such as stove and fridgeInsuite storageBalconiesHeat and water includedPowered outdoor parking stall included additional parking stall 50monthNeighbourhoodShort drive to Yellowhead Highway and Yellowhead Trail Anthony Henday Trail and nearby bus and transit stopsVictoria County is part of a larger neighbourhood community offering a variety of suite types for all of lifes stages Suites range from bachelor suites one two andthreebedroom suites to two and threebedroom townhomesQuick access to Canon Ridge Park Hermitage Park Belmont Park and Strathcona Science Provincial ParkClose to Hermitage Road Shopping Centre Clareview Village Shopping Centre Walmart Supercentre and MampM Food MarketNearby fitness and recreation facilities World Health Club and GoodLife Fitness Edmonton Clareview Town CentreClose to Riverview Medical Centre Medicentres Family Care Clinics and Health 1st Medical ClinicImagine home Its your safe and comfortable place to create unforgettable momentsMove in today And when you do theres always someone looking out for you supporting you along the wayBook a Viewing Herehttpsavenuelivingyuhuiobookshowingpropertyid4fc833eb79e8476ba3ef66c68af810dd                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# +-----------+------+-----------------+-------------------------------+-----------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------+--------------+----------+---------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows
#
# +--------------------------+-----------+--------------------+--------------------------+----------+----------------+-----------------+
# |unit_id                   |property_id|unit_name           |description               |squareFeet|availabilityDate|utilitiesIncluded|
# +--------------------------+-----------+--------------------+--------------------------+----------+----------------+-----------------+
# |554875_Unit_605           |554875     |Unit  605           |Unit A                    |578       |Immediate       |Heat             |
# |554875_Unit_606           |554875     |Unit  606           |Unit A                    |578       |Immediate       |Heat             |
# |554875_Unit_609           |554875     |Unit  609           |Unit A                    |578       |Immediate       |Heat             |
# |554875_Unit_706           |554875     |Unit  706           |Unit A                    |578       |Immediate       |Heat             |
# |540024_Unit_1E            |540024     |Unit  1E            |1 Bedroom 1 Bathroom + Den|656       |Immediate       |Heat, Water      |
# |549526_Studio_1_bath_1363 |549526     |Studio 1 bath $1363 |Studio                    |349       |Immediate       |Heat             |
# |549526_1_bed_1_bath_1608  |549526     |1 bed 1 bath $1608  |1 Bedroom                 |525       |Immediate       |Heat             |
# |549526_1_bed_1_bath_1282  |549526     |1 bed 1 bath $1282  |Junior 1                  |438       |Immediate       |Heat             |
# |549526_2_beds_2_baths_1820|549526     |2 beds 2 baths $1820|2 Bedroom                 |784       |Immediate       |Heat             |
# |549526_2_beds_2_baths_2194|549526     |2 beds 2 baths $2194|Junior 2                  |885       |Immediate       |Heat             |
# |561691_2_beds_2_baths_2410|561691     |2 beds 2 baths $2410|Jade I (2 Bed)            |1004      |Immediate       |Heat             |
# |561691_2_beds_2_baths_1950|561691     |2 beds 2 baths $1950|Jade II (2 Bed)           |936       |Immediate       |Heat             |
# |561691_2_beds_2_baths_2493|561691     |2 beds 2 baths $2493|Jade III (2 Bed)          |1018      |Immediate       |Heat             |
# |561691_2_beds_2_baths_2426|561691     |2 beds 2 baths $2426|Jade IV (2Bed)            |1011      |Immediate       |Heat             |
# |561691_2_beds_2_baths_2450|561691     |2 beds 2 baths $2450|Ruby I (3 Bed)            |1124      |Immediate       |Heat             |
# |561691_3_beds_2_baths_2450|561691     |3 beds 2 baths $2450|Ruby II (3 Bed)           |1124      |Immediate       |Heat             |
# |478927_Studio_1_bath_1167 |478927     |Studio 1 bath $1167 |Bachelor                  |462       |Immediate       |Heat, Water      |
# |478927_1_bed_1_bath_1352  |478927     |1 bed 1 bath $1352  |1 Bedroom                 |483       |Immediate       |Heat, Water      |
# |478927_1_bed_1_bath_1375  |478927     |1 bed 1 bath $1375  |1 Bedroom                 |850       |Immediate       |Heat, Water      |
# |478927_2_beds_1_bath_2009 |478927     |2 beds 1 bath $2009 |2 Bedroom                 |949       |Immediate       |Heat, Water      |
# +--------------------------+-----------+--------------------+--------------------------+----------+----------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# Step 2.3: Create Yelp Fusion API **parameters** and **headers** (5 pts)
#
# To begin, the first step is to create a Yelp Developer account, which you can accomplish by clicking [here](https://www.yelp.com/developers). After setting up your account, head to the Yelp Fusion API section on the Yelp Developer page and select 'Get Started.' This action will grant you access to API keys that are essential for fetching restaurant data, allowing you to perform queries based on addresses extracted from your rental listings. By integrating Yelp Fusion data with our scraped rental information, we can provide a comprehensive view of each listing's neighborhood amenities, enhancing the value of our dataset with actionable insights for potential renters.

# %%
# Your code goes here

# Import the necessary libraries
import requests
import json

# Define the API key and headers
api_key = 'k1kxfgEa-d8TRLwKrZA98CeflwwXqz_JG-U60cmEPVEMQktM2GtAmG7MYP5Ya16VQAD6JtMjFZ0rS2ohJy__F9QQ-raILMu7eME5WKw_fX7lbiYLtA-DFS7kvrQMZnYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# Define the search parameters

params = {
    'term': 'restaurants',
    'limit': 50
}

# %% [markdown]
# ## Part 3: Explore your data [Data Analysis - Total 30 pts]
#
# Now that you have created a PySpark dataframe with data from RentFaster and Kijiji, and your code is ready to make requests to the Yelp API, you can begin exploring your data!
#
# You can leverage the Yelp Fusion API, which offers a streamlined method to enrich our web-scraped housing data from RentFaster and Kijiji with detailed information about restaurants, including their ratings, based on specific addresses. This integration enables multi-dimensional analysis, providing insights into the dining landscape surrounding rental listings.
#
# To achieve this, perform the following steps:
#
# 1.   Get the top 50 listings with the highest price from both RentFaster and Kijiji
# (a total of 100 data points, refer to point 1 on **Appendix 1**).
# 2.   Get the bottom 50 listings with the lowest price from both RentFaster and Kijiji (a total of 100 data points, refer to point 2 on **Appendix 1**).
# 3.   Collect the addresses for the top 100 and bottom 100 listings.
# 4.   Perform data cleaning on your address data to remove duplicated locations, if any, from your top and bottom 100 listings.
# 5.  Once you have clean address data, use it to make requests to the Yelp API to obtain a list (in JSON format) of all restaurants near those locations (refer to point 3 on the **Appendix 1**)
# 6.  Create 2 tables using Spark: one for all the restaurants from the top 100 listings and another for those from the bottom 100 listings.
# 7.  Perform a data exploration analysis to try to explain the relationship, if any, between the top/bottom 100 listings and the nearby restaurants. Feel free to create new tables, dataframes, or whatever else you deem necessary for your analysis.
#
# **Apendix 1: Important things to consider!!!**
#
# 1.   The price information for Kijiji listings is stored within the Kijiji overview dataset, in a column called **price_info**. This price is within a JSON string. To retrieve it, use the following approach:
#
# ```
# from pyspark.sql import SparkSession
# from pyspark.sql.functions import col
#
# # Selecting the 'amt' key from the 'price_info' column along with other specified columns
# df = <your_spark_dataframe>.select(
#     col("property_id"),
#     col("listing_url"),
#     col("date_posted"),
#     col("price_info").getItem("amt").alias("amount")
# )
#
# # Show the resulting DataFrame
# df.show()
# ```
#
# 2.   The price information for RentFaster listings is stored within the RentFaster overview dataset, in a column called priceRange. As the name suggests, some listings will have a price range; for those, select the highest price. Use the following approach to clean up the data:
#
# ```
# from pyspark.sql.functions import col, split, expr, regexp_replace, when
#
# df = <your_spark_dataframe>.withColumn(
#     "highestPrice",  # Name of your new column
#     when(
#         col("priceRange").contains(" - "),  # Check if there's a range
#         expr("array_max(transform(split(regexp_replace(priceRange, '\\$|,', ''), ' - '), x -> cast(x as int)))") # Removing $ , - and converting to int
#     ).otherwise(
#         regexp_replace(col("priceRange"), '\\$|,', '').cast("int")  # Handle single price by removing $ and commas and converting to int
#     )
# )
# # Show the resulting DataFrame with the highest price extracted
# df.show(100)
# ```
#
#
#
# 3.   Once you have cleaned your address data, store the addresses in two lists: one for the top 100 listings and another for the bottom 100 listings. You will need to make requests to the API based on these addresses, with ONE request per address. If you have 50 addresses, you need to make 50 requests. **REMEMBER THAT YOU HAVE A DAILY LIMIT**. Here is a code snippet for reference:
#
# ```
# api_key_ = 'YOUR-KEY'
# address = "1039 McConachie Blvd. NW,Edmonton,AB,T5Y 3W5"
#
# headers = {
#     'Authorization': f'Bearer {api_key}',
# }
#
# params = {
#     'term': 'restaurants',
#     'location': address,
#     'limit': 50
# }
# ```
#
# Useful links:
#
# https://docs.developer.yelp.com/reference/v3_business_search
#
# https://spark.apache.org/docs/latest/api/sql/index.html
#
# https://spark.apache.org/docs/latest/sql-ref-functions.html
#
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/functions.html

# %%
kijiji_overview_df.dtypes
# Out:
# [('unit_id', 'string'),
#  ('listing_url', 'string'),
#  ('date_posted', 'string'),
#  ('address', 'string'),
#  ('price_info', 'string'),
#  ('description', 'string')]

# %%
rentfaster_overview_df.dtypes
# Out:
# [('property_id', 'string'),
#  ('id', 'string'),
#  ('location', 'string'),
#  ('name', 'string'),
#  ('url', 'string'),
#  ('slogan', 'string'),
#  ('priceRange', 'string'),
#  ('telephone', 'string'),
#  ('image', 'string'),
#  ('description', 'string'),
#  ('address', 'string'),
#  ('amenities', 'string')]

# %%
# step 1 Get the top 50 listings with the highest price from both RentFaster and Kijiji
from pyspark.sql.functions import col

# Get the top 50 Kijiji listings with the highest price
kijiji_top_50_df = kijiji_overview_df.sort(col("price_info").desc()).limit(50)

# Get the top 50 RentFaster listings with the highest price
rentfaster_top_50_df = rentfaster_overview_df.sort(col("priceRange").desc()).limit(50)

# Step 2: Get the bottom 50 listings with the lowest price from both RentFaster and Kijiji (a total of 100 data points)

# Get the bottom 50 Kijiji listings with the lowest price
kijiji_bottom_50_df = kijiji_overview_df.sort(col("price_info").asc()).limit(50)

# Get the bottom 50 RentFaster listings with the lowest price
rentfaster_bottom_50_df = rentfaster_overview_df.sort(col("priceRange").asc()).limit(50)

# Step 3: Collect the addresses for the top 100 and bottom 100 listings.

# Collect the addresses for the top 100 listings
top_100_addresses = []
if not kijiji_top_50_df.isEmpty():
    for row in kijiji_top_50_df.select("address").collect():
        top_100_addresses.append(row[0])
if not rentfaster_top_50_df.isEmpty():
    for row in rentfaster_top_50_df.select("address").collect():
        top_100_addresses.append(row[0])

# Collect the addresses for the bottom 100 listings
bottom_100_addresses = []
if not kijiji_bottom_50_df.isEmpty():
    for row in kijiji_bottom_50_df.select("address").collect():
        bottom_100_addresses.append(row[0])
if not rentfaster_bottom_50_df.isEmpty():
    for row in rentfaster_bottom_50_df.select("address").collect():
        bottom_100_addresses.append(row[0])
# Out:
# ["{'Undefined': 'Undefined'}",
#  "{'Undefined': 'Undefined'}",
#  "{'Undefined': 'Undefined'}",
#  "{'Undefined': 'Undefined'}",
#  "{'Undefined': 'Undefined'}",
#  "{'Undefined': 'Undefined'}",
#  "{'Undefined': 'Undefined'}",
#  "{'Undefined': 'Undefined'}",
#  "{'address_1': 'Athabasca, AB T9S 1A7'}",
#  "{'address_1': 'Lac la Biche, AB T0A 2C0'}",
#  "{'address_1': '32 Glencoe Blvd, Strathcona County, T8A 2Z6', 'address_2': '32 Glencoe Blvd, Strathcona County, T8A 2Z6'}",
#  "{'address_1': 'Lethbridge, AB T1J 5M9', 'address_2': 'Lethbridge, AB T1J 5M9'}",
#  "{'address_1': 'Sherwood Park, AB T8H 1W1'}",
#  "{'address_1': '#7-11703 51 Avenue NW, Edmonton, AB, T6H 0M4', 'address_2': '#7-11703 51 Avenue NW, Edmonton, AB, T6H 0M4'}",
#  "{'address_1': '332 Watt Dr SW, Edmonton, AB, T6X 0P6', 'address_2': '332 Watt Dr SW, Edmonton, AB, T6X 0P6'}",
#  "{'address_1': 'Drayton Valley, AB T7A'}",
#  "{'address_1': 'Drayton Valley, AB T7A'}",
#  "{'address_1': 'Cochrane, AB T4C 1B1'}",
#  "{'address_1': ', Edmonton T6B 0E8 AB, Canada'}",
#  "{'address_1': 'Edmonton, AB T6E 1S4'}",
#  "{'address_1': 'Calgary, AB T2E 7G1'}",
#  "{'address_1': 'Calgary, AB T2P 3K2'}",
#  "{'address_1': '74 Street Northwest, Edmonton, AB'}",
#  "{'address_1': '11231 Macdonald Drive, Fort McMurray, AB'}",
#  "{'address_1': 'AB-2, Red Deer, AB, T4P0L2'}",
#  "{'address_1': '7911 127 Ave NW, Edmonton, AB T5C'}",
#  "{'address_1': 'AB-2, Edmonton, AB, T6T0A5', 'address_2': 'AB-2, Edmonton, AB, T6T0A5'}",
#  "{'address_1': '9008 23 Ave NW, Edmonton, T6K 2W3'}",
#  "{'address_1': '5 Ave NE, Calgary, AB T2A 6K4'}",
#  "{'address_1': 'Martinvalley Crescent NE, Calgary, AB T3J'}",
#  "{'address_1': '5920 Macleod Trail SW, Calgary Alberta, Calgary, AB, T2H 0K2'}",
#  "{'address_1': 'Gasoline Alley west, Red Deer, AB, T4E 0A5'}",
#  "{'address_1': 'Lethbridge, AB T1K', 'address_2': 'Lethbridge, AB T1K'}",
#  "{'address_1': '41427 Range Rd 20, LACOMBE COUNTY, T0C 2J0', 'address_2': '41427 Range Rd 20, LACOMBE COUNTY, T0C 2J0'}",
#  "{'address_1': 'Fox Creek, AB T0H 1P0', 'address_2': 'Fox Creek, AB T0H 1P0'}",
#  "{'address_1': 'Banff Avenue, Banff, AB'}",
#  "{'address_1': '2520 - 52 Street NE, Calgary, AB, T1Y 3R6'}",
#  "{'address_1': '2520 - 52 Street NE, Calgary, AB, T1Y 3R6'}",
#  "{'address_1': '1013 17th Ave Sw, Calgary, AB, T2T 0A7'}",
#  "{'address_1': '5920 Macleod Trail SW, Calgary Alberta, Calgary, AB, T2H 0K2'}",
#  "{'address_1': '5920 Macleod Trail SW, Calgary Alberta, Calgary, AB, T2H 0K2'}",
#  "{'address_1': '5920 Macleod Trail SW, Calgary Alberta, Calgary, AB, T2H 0K2'}",
#  "{'address_1': '43 Street Southeast, Calgary, AB'}",
#  "{'address_1': '13703 135 Ave NW, Edmonton, AB'}",
#  "{'address_1': '11240 199th Street Northwest, Edmonton, AB'}",
#  "{'address_1': '12210 Mount Lawn Road Northwest, Edmonton, AB'}",
#  "{'Undefined': 'Undefined'}",
#  "{'address_1': 'Medicine Hat, AB T1A 0G8'}",
#  "{'address_1': '11405 132 St NW, Edmonton, AB, T5M 1G1', 'address_2': '11405 132 St NW, Edmonton, AB, T5M 1G1'}",
#  "{'address_1': '90 Sprague Way SE, Medicine Hat, AB, T1B 3M1', 'address_2': '90 Sprague Way SE, Medicine Hat, AB, T1B 3M1'}",
#  '11228 86 Street Northwest, Edmonton, Alberta, T5B3H8, CA',
#  '11405 132 St NW, Edmonton, Alberta, T5M1G1, CA',
#  'BSMT 9347 105 Avenue Northwest, Edmonton, Alberta, T5H0J6, CA',
#  '1472 (Bsmt) Keswick Drive Southwest - Bsmt Edmonton AB T6W 1A5, Edmonton, Alberta, T6W1A5, CA',
#  '11735 124 Street, Edmonton, Alberta, T5M0L1, CA',
#  '8621 112 STREET NW, Edmonton, Alberta, T6G1T1, CA',
#  '9950 90 Avenue Northwest, Edmonton, Alberta, T6E5A4, CA',
#  '123-127 Mount Pleasant Drive, Camrose, Alberta, T4V3G4, CA',
#  '123 Mount Pleasant Drive, Camrose, Alberta, T4V3G4, CA',
#  '6247 (bsmt) 176 Avenue Northwest, Edmonton, Alberta, T5Y4B8, CA',
#  '18035 Stony Plain Road, Edmonton, Alberta, T0B3M2, CA',
#  '202 - 10604 110 Avenue NW, Edmonton, Alberta, T5H4C7, CA',
#  '100 Mount Pleasant Drive, Camrose, Alberta, T4V2M6, CA',
#  '11545 124 Street, Edmonton, Alberta, T5M0K5, CA',
#  '13220 113A Street NW |\n13225 - 114  Street NW, Edmonton, Alberta, T5E5C1, CA',
#  '11615 124 Street NW, Edmonton, Alberta, T5M0K8, CA',
#  '10040 154 Street NW, Edmonton, Alberta, T5P2H1, CA',
#  '204-11043 108 St Nw, Edmonton, Alberta, T5H3A8, CA',
#  '1603-1615 Scenic Heights South, Lethbridge, Alberta, T1K1M5, CA',
#  'Undefined',
#  'Undefined',
#  '11212 85 Street Northwest, Edmonton, Alberta, T5B3C7, CA',
#  '11708 124 Street NW, Edmonton, Alberta, T5M0K9, CA',
#  '11624 124 Street NW, Edmonton, Alberta, T5M0K7, CA',
#  '10525 156 Street, Edmonton, Alberta, T5P2R8, CA',
#  '201 - 12103 67 Street Northwest, Edmonton, Alberta, T5W3R5, CA',
#  '10710 110 Street NW, Edmonton, Alberta, T5H3E1, CA',
#  'Undefined',
#  '5 - 11928 129 Avenue Northwest, Edmonton, Alberta, T5E0N3, CA',
#  '4 - 11928 129 Avenue Northwest, Edmonton, Alberta, T5E0N3, CA',
#  'Undefined',
#  '11446 92 Street, Edmonton, Alberta, T5G0Z5, CA',
#  '8222 Gateway Boulevard, Edmonton, Alberta, T6E4B2, CA',
#  '15625 18 Avenue Southwest, Edmonton, Alberta, T6W1A4, CA',
#  '4807 111A Street Northwest, Edmonton, Alberta, T6H3G4, CA',
#  '187 Grandin Village, St. Albert, Alberta, T8N2J3, CA',
#  '12711 118 Avenue NW, Edmonton, Alberta, T5L2K9, CA',
#  '5005 119 Avenue, Edmonton, Alberta, T5W1H6, CA',
#  '11837 106 St Nw, Edmonton, Alberta, T5G2R2, CA',
#  'Undefined',
#  'Undefined',
#  '1 - 10403 116 Avenue Northwest, Edmonton, Alberta, T5G0M2, CA',
#  'Undefined',
#  '8908 116 Street NW, Edmonton, Alberta, T6G1P8, CA',
#  '10530 111 St NW, Edmonton, Alberta, T5H0N9, CA',
#  'Undefined',
#  '17312 111 Street Northwest, Edmonton, Alberta, T5X3J8, CA',
#  'Undefined',
#  '9999 111 Street Northwest, Edmonton, Alberta, T5K1K3, CA',
#  '212 - 8510 111 Street Northwest, Edmonton, Alberta, T3K5Z1, CA']

# %%
# cleaning data

# Remove duplicate addresses from the top 100 addresses list
top_100_addresses = list(set(top_100_addresses))

# Remove duplicate addresses from the bottom 100 addresses list
bottom_100_addresses = list(set(bottom_100_addresses))

# %%
top_100_addresses
# Out:
# ['11708 124 Street NW, Edmonton, Alberta, T5M0K9, CA',
#  "{'address_1': '5 Ave NE, Calgary, AB T2A 6K4'}",
#  "{'address_1': '43 Street Southeast, Calgary, AB'}",
#  "{'address_1': '2520 - 52 Street NE, Calgary, AB, T1Y 3R6'}",
#  "{'address_1': '7911 127 Ave NW, Edmonton, AB T5C'}",
#  "{'address_1': 'Banff Avenue, Banff, AB'}",
#  '5 - 11928 129 Avenue Northwest, Edmonton, Alberta, T5E0N3, CA',
#  '204-11043 108 St Nw, Edmonton, Alberta, T5H3A8, CA',
#  '11624 124 Street NW, Edmonton, Alberta, T5M0K7, CA',
#  "{'address_1': '41427 Range Rd 20, LACOMBE COUNTY, T0C 2J0', 'address_2': '41427 Range Rd 20, LACOMBE COUNTY, T0C 2J0'}",
#  "{'address_1': 'Medicine Hat, AB T1A 0G8'}",
#  "{'address_1': 'Athabasca, AB T9S 1A7'}",
#  '11405 132 St NW, Edmonton, Alberta, T5M1G1, CA',
#  '17312 111 Street Northwest, Edmonton, Alberta, T5X3J8, CA',
#  '8621 112 STREET NW, Edmonton, Alberta, T6G1T1, CA',
#  "{'address_1': '9008 23 Ave NW, Edmonton, T6K 2W3'}",
#  "{'address_1': ', Edmonton T6B 0E8 AB, Canada'}",
#  '15625 18 Avenue Southwest, Edmonton, Alberta, T6W1A4, CA',
#  '8222 Gateway Boulevard, Edmonton, Alberta, T6E4B2, CA',
#  "{'address_1': 'Lethbridge, AB T1K', 'address_2': 'Lethbridge, AB T1K'}",
#  "{'address_1': 'AB-2, Edmonton, AB, T6T0A5', 'address_2': 'AB-2, Edmonton, AB, T6T0A5'}",
#  "{'address_1': '5920 Macleod Trail SW, Calgary Alberta, Calgary, AB, T2H 0K2'}",
#  '100 Mount Pleasant Drive, Camrose, Alberta, T4V2M6, CA',
#  "{'address_1': '11240 199th Street Northwest, Edmonton, AB'}",
#  '10530 111 St NW, Edmonton, Alberta, T5H0N9, CA',
#  "{'address_1': '90 Sprague Way SE, Medicine Hat, AB, T1B 3M1', 'address_2': '90 Sprague Way SE, Medicine Hat, AB, T1B 3M1'}",
#  '4 - 11928 129 Avenue Northwest, Edmonton, Alberta, T5E0N3, CA',
#  '9999 111 Street Northwest, Edmonton, Alberta, T5K1K3, CA',
#  "{'address_1': '74 Street Northwest, Edmonton, AB'}",
#  "{'address_1': 'Gasoline Alley west, Red Deer, AB, T4E 0A5'}",
#  "{'address_1': 'Calgary, AB T2P 3K2'}",
#  '11545 124 Street, Edmonton, Alberta, T5M0K5, CA',
#  'Undefined',
#  '5005 119 Avenue, Edmonton, Alberta, T5W1H6, CA',
#  '10040 154 Street NW, Edmonton, Alberta, T5P2H1, CA',
#  '11837 106 St Nw, Edmonton, Alberta, T5G2R2, CA',
#  "{'address_1': '11231 Macdonald Drive, Fort McMurray, AB'}",
#  "{'address_1': '32 Glencoe Blvd, Strathcona County, T8A 2Z6', 'address_2': '32 Glencoe Blvd, Strathcona County, T8A 2Z6'}",
#  '6247 (bsmt) 176 Avenue Northwest, Edmonton, Alberta, T5Y4B8, CA',
#  '8908 116 Street NW, Edmonton, Alberta, T6G1P8, CA',
#  "{'address_1': 'Cochrane, AB T4C 1B1'}",
#  '123-127 Mount Pleasant Drive, Camrose, Alberta, T4V3G4, CA',
#  '11446 92 Street, Edmonton, Alberta, T5G0Z5, CA',
#  "{'address_1': 'Martinvalley Crescent NE, Calgary, AB T3J'}",
#  '9950 90 Avenue Northwest, Edmonton, Alberta, T6E5A4, CA',
#  '13220 113A Street NW |\n13225 - 114  Street NW, Edmonton, Alberta, T5E5C1, CA',
#  "{'address_1': 'Calgary, AB T2E 7G1'}",
#  '1472 (Bsmt) Keswick Drive Southwest - Bsmt Edmonton AB T6W 1A5, Edmonton, Alberta, T6W1A5, CA',
#  "{'address_1': '#7-11703 51 Avenue NW, Edmonton, AB, T6H 0M4', 'address_2': '#7-11703 51 Avenue NW, Edmonton, AB, T6H 0M4'}",
#  '11615 124 Street NW, Edmonton, Alberta, T5M0K8, CA',
#  'BSMT 9347 105 Avenue Northwest, Edmonton, Alberta, T5H0J6, CA',
#  "{'address_1': '12210 Mount Lawn Road Northwest, Edmonton, AB'}",
#  '12711 118 Avenue NW, Edmonton, Alberta, T5L2K9, CA',
#  '11212 85 Street Northwest, Edmonton, Alberta, T5B3C7, CA',
#  "{'address_1': 'Lethbridge, AB T1J 5M9', 'address_2': 'Lethbridge, AB T1J 5M9'}",
#  "{'address_1': 'Sherwood Park, AB T8H 1W1'}",
#  "{'address_1': '1013 17th Ave Sw, Calgary, AB, T2T 0A7'}",
#  "{'address_1': '11405 132 St NW, Edmonton, AB, T5M 1G1', 'address_2': '11405 132 St NW, Edmonton, AB, T5M 1G1'}",
#  '10710 110 Street NW, Edmonton, Alberta, T5H3E1, CA',
#  "{'address_1': 'Lac la Biche, AB T0A 2C0'}",
#  '4807 111A Street Northwest, Edmonton, Alberta, T6H3G4, CA',
#  '123 Mount Pleasant Drive, Camrose, Alberta, T4V3G4, CA',
#  '201 - 12103 67 Street Northwest, Edmonton, Alberta, T5W3R5, CA',
#  '11228 86 Street Northwest, Edmonton, Alberta, T5B3H8, CA',
#  '202 - 10604 110 Avenue NW, Edmonton, Alberta, T5H4C7, CA',
#  "{'Undefined': 'Undefined'}",
#  '18035 Stony Plain Road, Edmonton, Alberta, T0B3M2, CA',
#  "{'address_1': 'Fox Creek, AB T0H 1P0', 'address_2': 'Fox Creek, AB T0H 1P0'}",
#  '187 Grandin Village, St. Albert, Alberta, T8N2J3, CA',
#  "{'address_1': 'Edmonton, AB T6E 1S4'}",
#  '10525 156 Street, Edmonton, Alberta, T5P2R8, CA',
#  '1 - 10403 116 Avenue Northwest, Edmonton, Alberta, T5G0M2, CA',
#  "{'address_1': 'Drayton Valley, AB T7A'}",
#  '1603-1615 Scenic Heights South, Lethbridge, Alberta, T1K1M5, CA',
#  '212 - 8510 111 Street Northwest, Edmonton, Alberta, T3K5Z1, CA',
#  "{'address_1': '332 Watt Dr SW, Edmonton, AB, T6X 0P6', 'address_2': '332 Watt Dr SW, Edmonton, AB, T6X 0P6'}",
#  '11735 124 Street, Edmonton, Alberta, T5M0L1, CA',
#  "{'address_1': 'AB-2, Red Deer, AB, T4P0L2'}",
#  "{'address_1': '13703 135 Ave NW, Edmonton, AB'}"]

# %%
bottom_100_addresses
# Out:
# ["{'address_1': 'Sherwood Park, AB T8H 1H4'}",
#  "{'address_1': 'Peace River, AB T8S 1R7', 'address_2': 'Peace River, AB T8S 1R7'}",
#  '1103 5 Ave S, Lethbridge, Alberta, T1J0V4, CA',
#  "{'address_1': '11832 88 Street, Edmonton, AB, T5B 3R8', 'address_2': '11832 88 Street, Edmonton, AB, T5B 3R8'}",
#  '400 Calahoo Road, Spruce Grove, Alberta, T7X2K7, CA',
#  '8615 106 Street, Edmonton, Alberta, T6E4J4, CA',
#  '301 - 5105 44 Street, Red Deer, Alberta, T4N1H9, CA',
#  '4703 104 Avenue Northwest, Edmonton, Alberta, T6A0X5, CA',
#  '22135 96 Avenue Northwest, Edmonton, Alberta, T5T1N1, CA',
#  '10020 103 Avenue, Edmonton, Alberta, T5J0G8, CA',
#  '721 7th Ave, Lethbridge, Alberta, T1J1J5, CA',
#  "{'address_1': 'Glendale Golf & Country Club, Edmonton, T5S2B9'}",
#  '1923 160 Street Southwest, Edmonton, Alberta, T6W1A6, CA',
#  "{'address_1': '3438 craig landing sw, Edmonton, AB, T6W 5B3', 'address_2': '3438 craig landing sw, Edmonton, AB, T6W 5B3'}",
#  "{'address_1': '11825 88 St, Edmonton, AB, T5B 3R9', 'address_2': '11825 88 St, Edmonton, AB, T5B 3R9'}",
#  "{'address_1': 'Brentwood Common Northwest, Brentwood, Calgary, AB'}",
#  '11262 78 Avenue Northwest, Edmonton, Alberta, T6G0M7, CA',
#  'Challand Ln, Edmonton, Alberta, T6W0C3, CA',
#  "{'address_1': '11825 101 Street, Edmonton, AB, T5G 2B6', 'address_2': '11825 101 Street, Edmonton, AB, T5G 2B6'}",
#  '10720 104 Street NW, Edmonton, Alberta, T5H2W5, CA',
#  "{'address_1': '18 Ave NE, Calgary, AB T2E 7T8, Canada'}",
#  "{'address_1': '5111 36 St, Lloydminster, AB, T9V 2A2', 'address_2': '5111 36 St, Lloydminster, AB, T9V 2A2'}",
#  '11330 124 Street NW, Edmonton, Alberta, T5M0K1, CA',
#  "{'address_1': '13124 126 St. NW, Edmonton, AB, T5L 0Y7', 'address_2': '13124 126 St. NW, Edmonton, AB, T5L 0Y7'}",
#  "{'address_1': '11811 67 St, Edmonton, AB, T5B 1L9', 'address_2': '11811 67 St, Edmonton, AB, T5B 1L9'}",
#  '2132 Palm Road S, Lethbridge, Alberta, T1K3M9, CA',
#  "{'address_1': '2132 Palm Road S, Lethbridge, AB, T1K 3M9', 'address_2': '2132 Palm Road S, Lethbridge, AB, T1K 3M9'}",
#  '10003 62 Street, Edmonton, Alberta, T6A2L6, CA',
#  '10210/10220 118 Street, Edmonton, Alberta, T5K1Y5, CA',
#  '4722 46 Street, Camrose, Alberta, T4V1G6, CA',
#  "{'address_1': 'Calgary, AB, T2C0M6'}",
#  '11303 52 Street Northwest, Edmonton, Alberta, T5W3J2, CA',
#  "{'address_1': '12408 117 Avenue, Edmonton, AB, T5M 3G7', 'address_2': '12408 117 Avenue, Edmonton, AB, T5M 3G7'}",
#  '4940 51 street, Red Deer, Alberta, T4N2A7, CA',
#  "{'address_1': '11008 83rd Street, Edmonton, AB, T5H 1M3', 'address_2': '11008 83rd Street, Edmonton, AB, T5H 1M3'}",
#  "{'address_1': '29 7th Street NE, Medicine Hat, AB, T1A 5P4', 'address_2': '29 7th Street NE, Medicine Hat, AB, T1A 5P4'}",
#  '11530 124 St NW, Edmonton, Alberta, T5M0K6, CA',
#  "{'address_1': '90 Sprague Way SE, Medicine Hat, AB, T1B 3M1', 'address_2': '90 Sprague Way SE, Medicine Hat, AB, T1B 3M1'}",
#  '201 - 10330 113 Street, Edmonton, Alberta, T5K1P6, CA',
#  '10022 – 110 Street NW, Edmonton, Alberta, T5K0M2, CA',
#  '590 & 600 Columbia Boulevard West, Lethbridge, Alberta, T1K5N8, CA',
#  'Undefined',
#  "{'address_1': '1617 2 Ave NE, Medicine Hat, AB, T1C 1A1', 'address_2': '1617 2 Ave NE, Medicine Hat, AB, T1C 1A1'}",
#  ' 2828 193 St NW, Edmonton, Alberta, T6M3B2, CA',
#  "{'address_1': '151 Mackenzie Way SW, Airdrie, T4B 2X7'}",
#  '5011 39 Street, Red Deer, Alberta, T4N0Z6, CA',
#  "{'address_1': '3402 51 Avenue, Red Deer, AB', 'address_2': '3402 51 Avenue, Red Deer, AB'}",
#  '12936 118 Avenue, Edmonton, Alberta, T5L2L4, CA',
#  '9208 106 Avenue Northwest, Edmonton, Alberta, T5H0N1, CA',
#  "{'address_1': '101-3116 116A Ave. NW, Edmonton, AB, T5W 4W6', 'address_2': '101-3116 116A Ave. NW, Edmonton, AB, T5W 4W6'}",
#  '11825 55 Street Northwest, Edmonton, Alberta, T5W3P7, CA',
#  "{'address_1': '150-8930 Jasper Ave. NW, Edmonton, AB, T5H 4E9', 'address_2': '150-8930 Jasper Ave. NW, Edmonton, AB, T5H 4E9'}",
#  '7 - 11928 129 Avenue Northwest, Edmonton, Alberta, T5E0N3, CA',
#  "{'address_1': '5104 56th Ave, Lloydminster, AB, T9V 0Z7', 'address_2': '5104 56th Ave, Lloydminster, AB, T9V 0Z7'}",
#  "{'address_1': '10125 153 Street, Edmonton, AB, T5P 2B3', 'address_2': '10125 153 Street, Edmonton, AB, T5P 2B3'}",
#  '11720 124 Street, Edmonton, Alberta, T5M0K9, CA',
#  "{'address_1': 'Calgary, AB T2A 7N7'}",
#  "{'address_1': '10651 105 Street, Edmonton, AB, T5H 2X1', 'address_2': '10651 105 Street, Edmonton, AB, T5H 2X1'}",
#  "{'address_1': '8510 111th Street, Edmonton, AB, T6G 1H7', 'address_2': '8510 111th Street, Edmonton, AB, T6G 1H7'}",
#  "{'address_1': '10711 Saskatchewan Dr., Edmonton, AB, T6E 4S4', 'address_2': '10711 Saskatchewan Dr., Edmonton, AB, T6E 4S4'}",
#  '12905 107 Ave, Edmonton, Alberta, T5M2A2, CA',
#  "{'address_1': '1658 3 Ave NE, Medicine Hat, AB, T1C 1A3', 'address_2': '1658 3 Ave NE, Medicine Hat, AB, T1C 1A3'}",
#  "{'address_1': 'Basement-2828 193 St NW, Edmonton, AB, T6M 3B2', 'address_2': 'Basement-2828 193 St NW, Edmonton, AB, T6M 3B2'}",
#  '12025 82 Street, Edmonton, Alberta, T5B2W5, CA',
#  "{'address_1': '10127 121 Street Northwest, Edmonton, AB', 'address_2': '10127 121 Street Northwest, Edmonton, AB'}",
#  "{'address_1': '12948 118 Avenue NW, Edmonton, AB, T5L 2L4', 'address_2': '12948 118 Avenue NW, Edmonton, AB, T5L 2L4'}",
#  '10145 121st Street, Edmonton, Alberta, T5N1K5, CA',
#  '102 Grosvenor Boulevard, St. Albert, Alberta, T8N0Y1, CA',
#  '9750 82  Avenue, Edmonton, Alberta, T6E1Y5, CA',
#  "{'address_1': 'Edmonton, AB T6E 0J1', 'address_2': 'Edmonton, AB T6E 0J1'}",
#  '12926 124 Street, Edmonton, Alberta, T5L0P5, CA',
#  '12408 117 Avenue, Edmonton, Alberta, T5M3G7, CA',
#  "{'address_1': '1103 5 Avenue S, Lethbridge, AB, T1J 0V4', 'address_2': '1103 5 Avenue S, Lethbridge, AB, T1J 0V4'}",
#  "{'address_1': '10803 113 St NW, Edmonton, AB, T5H 3J1', 'address_2': '10803 113 St NW, Edmonton, AB, T5H 3J1'}",
#  '10716 102 Street, Edmonton, Alberta, T5H2T7, CA',
#  '10058 102 St NW, Edmonton, Alberta, T5J3N7, CA',
#  "{'address_1': '6425 101 Ave. NW, Edmonton, AB, T6A 0H4', 'address_2': '6425 101 Ave. NW, Edmonton, AB, T6A 0H4'}",
#  'Hey there Step into this awesome basement suite in the lovely Hudson neighborhood super close to the Skyview Shopping Centre Its got 2 BEDROOMS Enter through your separate entrance and youll find cool LVP flooring leading to bright tiles The kitchen comes with appliances and theres a cozy fireplace ready to welcome you You also get your washer and dryer 2 comfy bedrooms and a handy storage room Perfect for a couple or anyone flying solo If you have any questions feel free to shoot us a message',
#  "{'address_1': '200 Lincoln Way SW, Calgary, AB T3E 6X7', 'address_2': '200 Lincoln Way SW, Calgary, AB T3E 6X7'}",
#  "{'address_1': '9925 Jasper Avenue NW, Edmonton, AB, T5J 2X5', 'address_2': '9925 Jasper Avenue NW, Edmonton, AB, T5J 2X5'}",
#  "{'address_1': '10315 156 Street, Edmonton, AB, T5P 2R4', 'address_2': '10315 156 Street, Edmonton, AB, T5P 2R4'}",
#  '11304 37 Avenue Northwest, Edmonton, Alberta, T6J0H5, CA',
#  '13830 150 Ave NW, Edmonton, Alberta, T6V1X2, CA',
#  "{'address_1': '3009 56 Ave, Lloydminster, AB, T9V 1Z6', 'address_2': '3009 56 Ave, Lloydminster, AB, T9V 1Z6'}",
#  '10125 153 Street, Edmonton, Alberta, T5P2B3, CA',
#  '10130 152 St, Edmonton, Alberta, T5P1X9, CA',
#  '10810 112 St, Edmonton, Alberta, T5H3H3, CA',
#  "{'address_1': '5635-47St, Lloydminster, AB, T9V 0H2', 'address_2': '5635-47St, Lloydminster, AB, T9V 0H2'}"]

# %%
#use it to make requests to the Yelp API to obtain a list (in JSON format) of all restaurants near those locations
api_key_2 = 'vngZ3zgNo-hT5qdxoOqPKI3E_QjHJBMLyuYlV0LQdYLSHf3YmXYGLJL-WAJgw2TpDaqR2qB-W9Hl_02wB06-QcmHQ1mPo-ocrNSiuDSRXoIElUZ2LX-AXkNiyfx3ZXYx'
top_100_addresses = []
bottom_100_addresses = []

# Collect the addresses for the top 100 listings
if not kijiji_top_50_df.isEmpty():
    for row in kijiji_top_50_df.select("address").collect():
        top_100_addresses.append(row[0])
if not rentfaster_top_50_df.isEmpty():
    for row in rentfaster_top_50_df.select("address").collect():
        top_100_addresses.append(row[0])

# Collect the addresses for the bottom 100 listings
if not kijiji_bottom_50_df.isEmpty():
    for row in kijiji_bottom_50_df.select("address").collect():
        bottom_100_addresses.append(row[0])
if not rentfaster_bottom_50_df.isEmpty():
    for row in rentfaster_bottom_50_df.select("address").collect():
        bottom_100_addresses.append(row[0])

# Clean the address data
top_100_addresses = list(set(top_100_addresses))
bottom_100_addresses = list(set(bottom_100_addresses))

# Make requests to the Yelp API
top_100_restaurants = []
bottom_100_restaurants = []
#api_key_2 = 'vngZ3zgNo-hT5qdxoOqPKI3E_QjHJBMLyuYlV0LQdYLSHf3YmXYGLJL-WAJgw2TpDaqR2qB-W9Hl_02wB06-QcmHQ1mPo-ocrNSiuDSRXoIElUZ2LX-AXkNiyfx3ZXYx'
for address in top_100_addresses:
    response = requests.get(
        "https://api.yelp.com/v3/businesses/search",
        headers=headers,
        params={"term": "restaurants", "location": '123-127 Mount Pleasant Drive, Camrose, Alberta, T4V3G4, CA', "limit": 1},
    )
    top_100_restaurants.append(response.json())

for address in bottom_100_addresses:
    response = requests.get(
        "https://api.yelp.com/v3/businesses/search",
        headers=headers,
        params={"term": "restaurants", "location": '8908 116 Street NW, Edmonton, Alberta, T6G1P8, CA', "limit": 1},
    )
    bottom_100_restaurants.append(response.json())

# %%
endpoint_url = 'https://api.yelp.com/v3/businesses/search'
response = requests.get(endpoint_url, headers=headers, params=params)
yelp_ata = response.json()

# %%
top_100_restaurants
# Out:
# [{'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
# ...
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}},
#  {'businesses': [{'id': 'drM2KnHGohONfE8f8Ue-Rw',
#     'alias': 'steampunk-cafe-camrose-3',
#     'name': 'SteamPunk Cafe',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 10,
#     'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#      {'alias': 'cafes', 'title': 'Cafes'},
#      {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#     'rating': 3.9,
#     'coordinates': {'latitude': 53.0237022257835,
#      'longitude': -112.82481816547408},
#     'transactions': [],
#     'location': {'address1': '5078 50 Street',
#      'address2': '',
#      'address3': '',
#      'city': 'Camrose',
#      'zip_code': 'T4V 1R2',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['5078 50 Street', 'Camrose, AB T4V 1R2', 'Canada']},
#     'phone': '+17806724730',
#     'display_phone': '+1 780-672-4730',
#     'distance': 2323.1993462741293,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': None,
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 53,
#   'region': {'center': {'longitude': -112.84503936767578,
#     'latitude': 53.00671607559576}}}]

# %%
bottom_100_restaurants
# Out:
# [{'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
# ...
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}},
#  {'businesses': [{'id': 'oO1BUhSRwHIrnULwb_XIjQ',
#     'alias': 'la-petite-iza-edmonton',
#     'name': 'La Petite Iza',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A',
#     'review_count': 25,
#     'categories': [{'alias': 'french', 'title': 'French'},
#      {'alias': 'bistros', 'title': 'Bistros'}],
#     'rating': 4.4,
#     'coordinates': {'latitude': 53.523992, 'longitude': -113.513261},
#     'transactions': [],
#     'location': {'address1': '10926 88 Avenue NW',
#      'address2': 'Floor 3',
#      'address3': None,
#      'city': 'Edmonton',
#      'zip_code': 'T6G 0Z1',
#      'country': 'CA',
#      'state': 'AB',
#      'display_address': ['10926 88 Avenue NW',
#       'Floor 3',
#       'Edmonton, AB T6G 0Z1',
#       'Canada']},
#     'phone': '+17804350083',
#     'display_phone': '+1 780-435-0083',
#     'distance': 1176.9623392733852,
#     'attributes': {'business_temp_closed': None,
#      'menu_url': 'https://www.lapetiteiza.com/menu',
#      'open24_hours': None,
#      'waitlist_reservation': None}}],
#   'total': 1800,
#   'region': {'center': {'longitude': -113.53099822998047,
#     'latitude': 53.52499191310497}}}]

# %%
# creating tables
from pyspark.sql import SparkSession
# Create a Spark DataFrame for the top 100 restaurants
spark = SparkSession.builder.getOrCreate()
# Create a Spark DataFrame for the top 100 restaurants
top_100_df = spark.createDataFrame(top_100_restaurants)

# Create a Spark DataFrame for the bottom 100 restaurants
bottom_100_df = spark.createDataFrame(bottom_100_restaurants)

# %%
from pyspark.sql import SparkSession

# Initialize SparkSession
spark = SparkSession.builder \
    .appName("Top and Bottom Restaurants") \
    .getOrCreate()

# Assuming restaurants_df is your DataFrame containing restaurant listings

# Filter top 100 restaurants
top_100_df = top_100_df.orderBy("total").limit(100)

# Filter bottom 100 restaurants
bottom_100_df = bottom_100_df.orderBy("total", ascending=False).limit(100)

# Register DataFrames as tables
top_100_df.createOrReplaceTempView("top_restaurants")
bottom_100_df.createOrReplaceTempView("bottom_restaurants")


spark.stop()

# %%
top_100_df.createOrReplaceTempView("top_restaurants")

# %%
print(type(top_100_restaurants))
print(type(bottom_100_restaurants))
# Out:
# <class 'list'>
# <class 'list'>

# %%
top_100_restaurants_df = pd.DataFrame(top_100_restaurants)
bottom_100_restaurants_df = pd.DataFrame(bottom_100_restaurants)

# %%
# Create a Spark DataFrame for the top 100 restaurants
top_100_df = spark.createDataFrame(top_100_restaurants)

# Create a Spark DataFrame for the bottom 100 restaurants
bottom_100_df = spark.createDataFrame(bottom_100_restaurants)

# Print the schema of the DataFrames
top_100_df.printSchema()
bottom_100_df.printSchema()

# Show the first few rows of the DataFrames
top_100_df.show(truncate=False)
bottom_100_df.show(truncate=False)
# Out:
# root
#  |-- businesses: array (nullable = true)
#  |    |-- element: map (containsNull = true)
#  |    |    |-- key: string
#  |    |    |-- value: string (valueContainsNull = true)
#  |-- region: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: map (valueContainsNull = true)
#  |    |    |-- key: string
#  |    |    |-- value: double (valueContainsNull = true)
#  |-- total: long (nullable = true)
#
# root
#  |-- businesses: array (nullable = true)
#  |    |-- element: map (containsNull = true)
#  |    |    |-- key: string
#  |    |    |-- value: string (valueContainsNull = true)
#  |-- region: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: map (valueContainsNull = true)
#  |    |    |-- key: string
#  |    |    |-- value: double (valueContainsNull = true)
#  |-- total: long (nullable = true)
#
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------+-----+
# |businesses                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |region                                                                       |total|
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------+-----+
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# |[{distance -> 2323.1993462741293, image_url -> https://s3-media4.fl.yelpcdn.com/bphoto/7BjZX_aKjHSo5B21dXK20Q/o.jpg, coordinates -> {latitude=53.0237022257835, longitude=-112.82481816547408}, rating -> 3.9, review_count -> 10, transactions -> [], url -> https://www.yelp.com/biz/steampunk-cafe-camrose-3?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-672-4730, phone -> +17806724730, name -> SteamPunk Cafe, alias -> steampunk-cafe-camrose-3, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=null}, location -> {country=CA, address3=, city=Camrose, address2=, address1=5078 50 Street, display_address=[5078 50 Street, Camrose, AB T4V 1R2, Canada], state=AB, zip_code=T4V 1R2}, categories -> [{title=Steakhouses, alias=steak}, {title=Cafes, alias=cafes}, {title=Sandwiches, alias=sandwiches}], id -> drM2KnHGohONfE8f8Ue-Rw, is_closed -> false}]|{center -> {latitude -> 53.00671607559576, longitude -> -112.84503936767578}}|53   |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------+-----+
# only showing top 20 rows
#
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------+-----+
# |businesses                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |region                                                                       |total|
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------+-----+
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# |[{distance -> 1176.9623392733852, image_url -> https://s3-media3.fl.yelpcdn.com/bphoto/9klgriKUEh-Q9pnZ9xi6UA/o.jpg, coordinates -> {latitude=53.523992, longitude=-113.513261}, rating -> 4.4, review_count -> 25, transactions -> [], url -> https://www.yelp.com/biz/la-petite-iza-edmonton?adjust_creative=y08HjsQg9wC6r7GlYYLL9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y08HjsQg9wC6r7GlYYLL9A, display_phone -> +1 780-435-0083, phone -> +17804350083, name -> La Petite Iza, alias -> la-petite-iza-edmonton, attributes -> {waitlist_reservation=null, open24_hours=null, business_temp_closed=null, menu_url=https://www.lapetiteiza.com/menu}, location -> {country=CA, address3=null, city=Edmonton, address2=Floor 3, address1=10926 88 Avenue NW, display_address=[10926 88 Avenue NW, Floor 3, Edmonton, AB T6G 0Z1, Canada], state=AB, zip_code=T6G 0Z1}, categories -> [{title=French, alias=french}, {title=Bistros, alias=bistros}], id -> oO1BUhSRwHIrnULwb_XIjQ, is_closed -> false}]|{center -> {latitude -> 53.52499191310497, longitude -> -113.53099822998047}}|1800 |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------+-----+
# only showing top 20 rows

# %% [markdown]
# ## Part 4: Presentation (30 pts)
#
# You will need to create a presentation that would last 10 to 15 min. All memebers for the group should participate. This presentation will be conducted on Monday 22th and Tuesday 23th of April.
#
# In this presentation you will need to explain your findings from your data collection, managmenet and exploration. This must include everything such as corrupted data, data cleaning, data transformation, errors when scraping from websitews, data analysis, data limitations etc. You should showcase your work in its fullest!
#
# What we are specifically looking is the following:
# *   Issues faced acquiring your data, this could be limitations with the webscraping procedure
# *   Data quality issues such as missing values or difficulties when working with multiple datatypes and how to solve/consider those in your analysis
# *   The highlights and correlations that you derived based on the analysis of the data, you should be able to answer the following questions:
#   * Is there a correlation between the rental price vs the quality/price on restaurants near by?
#   * Is the data coming from Yelp of enough quality to drive insides?
#   * What you would do better or different to arrive to a more conclusive analysis?
#   * What are your next steps?
#   * Is this datapipeline you built enough to scale for big data?
